# %% [markdown]
# # ROSE产品数据解析
#
# Use metradar to read information from a rose product file and plot

# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from metradar.io.decode_pup_rose import READ_ROSE
import pyart
from metradar.graph.draw_latlon_func import draw_latlon
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119

# %%
 
decoder = READ_ROSE()
rootpath = '/mnt/e/metradar_test/rose_product'
outpath = '/mnt/e/metradar_test/rose_product/pic'
staid = 'Z9778'
timestr = '20250508123200'

# %% [markdown]
# ## PPI-回波强度

# %%
ptype='PPI'
filepath= rootpath + '/' + staid + '/' + ptype + '/19/'
filename = f'{staid}_{timestr}Z_{ptype}_04_19'
data_ppi = decoder.read_ppi(filepath,filename)
outname = f'{filename}.png'
tstr =timestr[0:8]+'_'+timestr[8:14]
draw_latlon(data_ppi.data,data_ppi.lat.data,data_ppi.lon.data,data_ppi.lat.min(),data_ppi.lat.max(),data_ppi.lon.min(),data_ppi.lon.max(),outpath,outname,tstr,
            add_title=1,badd_gis=True,
            prefix_title='反射率因子',units='dBZ',thred=0,dpi=300)
# Out:
# 数据类型: 2-滤波后反射率(Reflectivity)
# 352 920
# /mnt/e/metradar_test/rose_product/pic/Z9778_20250508123200Z_PPI_04_19.png saved!

# %% [markdown]
# ## PPI-径向速度

# %%
ptype='PPI'
filepath= rootpath + '/' + staid + '/' + ptype + '/26/'
filename = f'{staid}_{timestr}Z_{ptype}_04_26'
data_ppi = decoder.read_ppi(filepath,filename)
outname = f'{filename}.png'
tstr =timestr[0:8]+'_'+timestr[8:14]
draw_latlon(data_ppi.data,data_ppi.lat.data,data_ppi.lon.data,data_ppi.lat.min(),data_ppi.lat.max(),data_ppi.lon.min(),data_ppi.lon.max(),outpath,outname,tstr,
            add_title=1,badd_gis=True,
            prefix_title='径向速度',units='m/s',thred=-999,dpi=300)
# Out:
# 数据类型: 3-径向速度(Doppler Velocity)
# 352 460
# /mnt/e/metradar_test/rose_product/pic/Z9778_20250508123200Z_PPI_04_26.png saved!

# %% [markdown]
# ## SS-风暴属性

# %%
#ss
ptype='SS'
filepath= rootpath + '/' + staid + '/' + ptype + '/62/'
filename = f'{staid}_{timestr}Z_{ptype}_00_62'
data_ss = decoder.read_ss(filepath,filename)
data_ss
# Out:
# {'ss': [{'storm_id': 1,
#    'azi': 278.80078125,
#    'range': 93604,
#    'base': 1416,
#    'top': 14575,
#    'vil': 76.22551727294922,
#    'mref': 64.5,
#    'hmref': 7356,
#    'id_char': 'A0',
#    'lon': np.float64(106.58960795900846),
#    'lat': np.float64(25.115412606232596)},
#   {'storm_id': 23,
#    'azi': 275.448974609375,
#    'range': 172132,
#    'base': 3415,
#    'top': 14471,
#    'vil': 63.077693939208984,
#    'mref': 62.5,
#    'hmref': 8991,
#    'id_char': 'W0',
#    'lon': np.float64(105.80642733315258),
#    'lat': np.float64(25.12673885979999)},
#   {'storm_id': 9,
#    'azi': 284.42352294921875,
#    'range': 138711,
#    'base': 2427,
#    'top': 15702,
#    'vil': 55.535186767578125,
#    'mref': 57.5,
#    'hmref': 6849,
#    'id_char': 'I0',
#    'lon': np.float64(106.1721828246575),
#    'lat': np.float64(25.294170026078174)},
#   {'storm_id': 47,
#    'azi': 227.41697692871094,
#    'range': 23519,
#    'base': 195,
#    'top': 10626,
#    'vil': 49.15811538696289,
#    'mref': 70.5,
#    'hmref': 9055,
#    'id_char': 'U1',
#    'lon': np.float64(107.33671098189464),
#    'lat': np.float64(24.846225796463372)},
#   {'storm_id': 71,
#    'azi': 105.7766342163086,
#    'range': 30401,
#    'base': 1425,
#    'top': 9280,
#    'vil': 42.98295974731445,
#    'mref': 62.5,
#    'hmref': 6309,
#    'id_char': 'S2',
#    'lon': np.float64(107.79843203955167),
#    'lat': np.float64(24.91482901218026)},
#   {'storm_id': 2,
#    'azi': 225.35731506347656,
#    'range': 29856,
#    'base': 2309,
#    'top': 10609,
#    'vil': 37.14077377319336,
#    'mref': 70.5,
#    'hmref': 8945,
#    'id_char': 'B0',
#    'lon': np.float64(107.29788377305752),
#    'lat': np.float64(24.800626061442586)},
#   {'storm_id': 11,
#    'azi': 85.54539489746094,
#    'range': 27051,
#    'base': 277,
#    'top': 7177,
#    'vil': 36.04310607910156,
#    'mref': 60.5,
#    'hmref': 3328,
#    'id_char': 'K0',
#    'lon': np.float64(107.77596227479252),
#    'lat': np.float64(25.008100339182892)},
#   {'storm_id': 46,
#    'azi': 84.36976623535156,
#    'range': 17006,
#    'base': 141,
#    'top': 3462,
#    'vil': 28.844806671142578,
#    'mref': 60.5,
#    'hmref': 3183,
#    'id_char': 'T1',
#    'lon': np.float64(107.67627217264157),
#    'lat': np.float64(25.004354980825333)},
#   {'storm_id': 38,
#    'azi': 280.6893310546875,
#    'range': 154098,
#    'base': 5403,
#    'top': 13095,
#    'vil': 25.075742721557617,
#    'mref': 61.5,
#    'hmref': 5403,
#    'id_char': 'L1',
#    'lon': np.float64(106.00296161942234),
#    'lat': np.float64(25.238886065712382)},
#   {'storm_id': 37,
#    'azi': 291.9075927734375,
#    'range': 125897,
#    'base': 2097,
#    'top': 6102,
#    'vil': 23.96936798095703,
#    'mref': 55.0,
#    'hmref': 2097,
#    'id_char': 'K1',
#    'lon': np.float64(106.34547518609314),
#    'lat': np.float64(25.407330447100662)},
#   {'storm_id': 16,
#    'azi': 74.37786102294922,
#    'range': 75327,
#    'base': 958,
#    'top': 9226,
#    'vil': 21.67021369934082,
#    'mref': 54.0,
#    'hmref': 3482,
#    'id_char': 'P0',
#    'lon': np.float64(108.22916738252577),
#    'lat': np.float64(25.170129419342857)},
#   {'storm_id': 72,
#    'azi': 91.17333984375,
#    'range': 208119,
#    'base': 4557,
#    'top': 8023,
#    'vil': 20.498598098754883,
#    'mref': 51.0,
#    'hmref': 4557,
#    'id_char': 'T2',
#    'lon': np.float64(109.57165452637491),
#    'lat': np.float64(24.93690265579285)},
#   {'storm_id': 6,
#    'azi': 108.91486358642578,
#    'range': 185778,
#    'base': 3792,
#    'top': 6965,
#    'vil': 20.444467544555664,
#    'mref': 52.0,
#    'hmref': 3792,
#    'id_char': 'F0',
#    'lon': np.float64(109.24413173848139),
#    'lat': np.float64(24.437894845707252)},
#   {'storm_id': 21,
#    'azi': 106.94145202636719,
#    'range': 19625,
#    'base': 3104,
#    'top': 7393,
#    'vil': 20.43720054626465,
#    'mref': 62.0,
#    'hmref': 3104,
#    'id_char': 'U0',
#    'lon': np.float64(107.69452331433955),
#    'lat': np.float64(24.937900253853094)},
#   {'storm_id': 58,
#    'azi': 81.8488540649414,
#    'range': 96144,
#    'base': 1354,
#    'top': 6135,
#    'vil': 17.951778411865234,
#    'mref': 52.5,
#    'hmref': 3019,
#    'id_char': 'F2',
#    'lon': np.float64(108.45352972115802),
#    'lat': np.float64(25.109046163283665)},
#   {'storm_id': 10,
#    'azi': 79.08042907714844,
#    'range': 100628,
#    'base': 1348,
#    'top': 9020,
#    'vil': 13.657928466796875,
#    'mref': 50.5,
#    'hmref': 1348,
#    'id_char': 'J0',
#    'lon': np.float64(108.49000029949998),
#    'lat': np.float64(25.157643433901786)},
#   {'storm_id': 26,
#    'azi': 89.29173278808594,
#    'range': 55723,
#    'base': 657,
#    'top': 9352,
#    'vil': 12.950454711914062,
#    'mref': 52.0,
#    'hmref': 2554,
#    'id_char': 'Z0',
#    'lon': np.float64(108.06119334836112),
#    'lat': np.float64(24.994617873726266)},
#   {'storm_id': 56,
#    'azi': 70.95120239257812,
#    'range': 94368,
#    'base': 1281,
#    'top': 8116,
#    'vil': 11.438608169555664,
#    'mref': 49.5,
#    'hmref': 1281,
#    'id_char': 'D2',
#    'lon': np.float64(108.39534101693611),
#    'lat': np.float64(25.263785153720363)},
#   {'storm_id': 68,
#    'azi': 77.87834167480469,
#    'range': 116762,
#    'base': 1850,
#    'top': 5629,
#    'vil': 10.909649848937988,
#    'mref': 49.0,
#    'hmref': 3901,
#    'id_char': 'P2',
#    'lon': np.float64(108.64296411515511),
#    'lat': np.float64(25.205626487447038)},
#   {'storm_id': 57,
#    'azi': 83.66592407226562,
#    'range': 66763,
#    'base': 3055,
#    'top': 6662,
#    'vil': 10.070469856262207,
#    'mref': 52.5,
#    'hmref': 4048,
#    'id_char': 'E2',
#    'lon': np.float64(108.1670510754327),
#    'lat': np.float64(25.054234027565563)},
#   {'storm_id': 49,
#    'azi': 68.27226257324219,
#    'range': 63215,
#    'base': 742,
#    'top': 8843,
#    'vil': 8.648487091064453,
#    'mref': 48.0,
#    'hmref': 1796,
#    'id_char': 'W1',
#    'lon': np.float64(108.09198024288557),
#    'lat': np.float64(25.19876065469363)},
#   {'storm_id': 73,
#    'azi': 88.06449127197266,
#    'range': 263786,
#    'base': 6717,
#    'top': 11224,
#    'vil': 6.535282611846924,
#    'mref': 39.5,
#    'hmref': 6717,
#    'id_char': 'U2',
#    'lon': np.float64(110.12468169378234),
#    'lat': np.float64(25.0466604030195)},
#   {'storm_id': 44,
#    'azi': 12.890445709228516,
#    'range': 46897,
#    'base': 505,
#    'top': 3743,
#    'vil': 5.861883640289307,
#    'mref': 47.5,
#    'hmref': 3743,
#    'id_char': 'R1',
#    'lon': np.float64(107.61248638870309),
#    'lat': np.float64(25.40053039672606)},
#   {'storm_id': 61,
#    'azi': 86.48677825927734,
#    'range': 81693,
#    'base': 1109,
#    'top': 3769,
#    'vil': 5.611355781555176,
#    'mref': 46.5,
#    'hmref': 2529,
#    'id_char': 'I2',
#    'lon': np.float64(108.31763352467004),
#    'lat': np.float64(25.032274907789418)},
#   {'storm_id': 81,
#    'azi': 274.880859375,
#    'range': 103244,
#    'base': 6535,
#    'top': 8318,
#    'vil': 4.562286376953125,
#    'mref': 49.0,
#    'hmref': 6535,
#    'id_char': 'C3',
#    'lon': np.float64(106.48706461659148),
#    'lat': np.float64(25.064954766762938)},
#   {'storm_id': 34,
#    'azi': 154.83177185058594,
#    'range': 7153,
#    'base': 146,
#    'top': 1353,
#    'vil': 4.4698381423950195,
#    'mref': 53.5,
#    'hmref': 1189,
#    'id_char': 'H1',
#    'lon': np.float64(107.53850004293945),
#    'lat': np.float64(24.93122035529446)},
#   {'storm_id': 82,
#    'azi': 289.6528625488281,
#    'range': 101143,
#    'base': 1495,
#    'top': 4877,
#    'vil': 4.376711368560791,
#    'mref': 42.0,
#    'hmref': 1495,
#    'id_char': 'D3',
#    'lon': np.float64(106.56093631347268),
#    'lat': np.float64(25.292344825213657)},
#   {'storm_id': 63,
#    'azi': 69.60863494873047,
#    'range': 118275,
#    'base': 3886,
#    'top': 7466,
#    'vil': 4.125371932983398,
#    'mref': 46.0,
#    'hmref': 3886,
#    'id_char': 'K2',
#    'lon': np.float64(108.61156955213633),
#    'lat': np.float64(25.35596378825359)},
#   {'storm_id': 59,
#    'azi': 86.54585266113281,
#    'range': 186866,
#    'base': 3820,
#    'top': 7039,
#    'vil': 3.712129592895508,
#    'mref': 38.5,
#    'hmref': 3820,
#    'id_char': 'G2',
#    'lon': np.float64(109.36017337071934),
#    'lat': np.float64(25.0792156672782)},
#   {'storm_id': 79,
#    'azi': 285.1464538574219,
#    'range': 13321,
#    'base': 129,
#    'top': 1338,
#    'vil': 3.6573221683502197,
#    'mref': 52.0,
#    'hmref': 593,
#    'id_char': 'A3',
#    'lon': np.float64(107.3807185647867),
#    'lat': np.float64(25.020692147658707)},
#   {'storm_id': 83,
#    'azi': 122.23287963867188,
#    'range': 19139,
#    'base': 2953,
#    'top': 3356,
#    'vil': 3.395864248275757,
#    'mref': 53.0,
#    'hmref': 3356,
#    'id_char': 'E3',
#    'lon': np.float64(107.6688439112457),
#    'lat': np.float64(24.897555938819625)},
#   {'storm_id': 84,
#    'azi': 271.69287109375,
#    'range': 48657,
#    'base': 4681,
#    'top': 5360,
#    'vil': 3.1031839847564697,
#    'mref': 49.0,
#    'hmref': 5360,
#    'id_char': 'F3',
#    'lon': np.float64(107.02572048068743),
#    'lat': np.float64(25.001593301896815)},
#   {'storm_id': 75,
#    'azi': 17.482789993286133,
#    'range': 8539,
#    'base': 1840,
#    'top': 1892,
#    'vil': 3.0328357219696045,
#    'mref': 50.5,
#    'hmref': 2081,
#    'id_char': 'W2',
#    'lon': np.float64(107.5337993678239),
#    'lat': np.float64(25.06268836175304)},
#   {'storm_id': 85,
#    'azi': 298.4501953125,
#    'range': 120863,
#    'base': 3993,
#    'top': 5695,
#    'vil': 2.9043190479278564,
#    'mref': 44.5,
#    'hmref': 3993,
#    'id_char': 'G3',
#    'lon': np.float64(106.44955176247908),
#    'lat': np.float64(25.503471755255546)},
#   {'storm_id': 65,
#    'azi': 72.8608169555664,
#    'range': 104360,
#    'base': 6702,
#    'top': 9356,
#    'vil': 2.849855899810791,
#    'mref': 40.0,
#    'hmref': 6702,
#    'id_char': 'M2',
#    'lon': np.float64(108.499986155324),
#    'lat': np.float64(25.26272077560556)},
#   {'storm_id': 86,
#    'azi': 338.5548400878906,
#    'range': 105482,
#    'base': 3380,
#    'top': 5059,
#    'vil': 2.105862617492676,
#    'mref': 40.0,
#    'hmref': 3380,
#    'id_char': 'H3',
#    'lon': np.float64(107.12290550625654),
#    'lat': np.float64(25.871848887035778)},
#   {'storm_id': 13,
#    'azi': 57.40081787109375,
#    'range': 49319,
#    'base': 558,
#    'top': 2363,
#    'vil': 1.9785871505737305,
#    'mref': 43.5,
#    'hmref': 558,
#    'id_char': 'M0',
#    'lon': np.float64(107.921385578448),
#    'lat': np.float64(25.227830607001266)},
#   {'storm_id': 80,
#    'azi': 50.24363708496094,
#    'range': 59303,
#    'base': 693,
#    'top': 2855,
#    'vil': 0.958709180355072,
#    'mref': 35.0,
#    'hmref': 693,
#    'id_char': 'B3',
#    'lon': np.float64(107.96193735209151),
#    'lat': np.float64(25.329824957492697)}]}

# %% [markdown]
# ## STI-风暴路径

# %%
#ss
ptype='STI'
filepath= rootpath + '/' + staid + '/' + ptype + '/58/'
filename = f'{staid}_{timestr}Z_{ptype}_00_58'
data_sti = decoder.read_sti(filepath,filename)
data_sti
# Out:
# {'dic_gh': {'magic_number': 1297371986,
#   'major_version': 1,
#   'minor_version': 1,
#   'generic_type': 2,
#   'product_type': 37,
#   'reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'},
#  'dic_scfg': {'site_code': b'Z9778\x00\x00\x00',
#   'site_name': b'HeChi_Z9778\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#   'lat': 24.989444732666016,
#   'lon': 107.50833129882812,
#   'ana_height': 1047,
#   'grd_height': 1027,
#   'freq': 2830.0,
#   'beamwidth_h': 0.8799999952316284,
#   'beamwidth_v': 0.8799999952316284,
#   'rda_version': 789002,
#   'radar_type': 2,
#   'reserved': b'\xc1\x11\x18\xffZ\xff\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'},
#  'dic_tcfg': {'task_name': b'VCP11\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#   'task_disp': b'VCP11',
#   'pol_type': 1,
#   'scan_type': 0,
#   'pulse_wid': 1570,
#   'scan_stime': 1746707520,
#   'cut_number': 16,
#   'hor_noise': -83.9455337524414,
#   'ver_noise': nan,
#   'hor_calib': 41.348262786865234,
#   'ver_calib': -999999.0,
#   'hor_noise_t': 250.58322143554688,
#   'ver_noise_t': 0.0,
#   'zdr_calib': -0.05999999865889549,
#   'phi_calib': 40.0,
#   'ldr_calib': 0.0,
#   'reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'},
#  'cutinfo': [{'process_mod': 1,
#    'wave_form': 0,
#    'prf1': 322.0,
#    'prf2': -999999.0,
#    'dias_mode': 1,
#    'azimuth': -999999.0,
#    'elevation': 0.4833984375,
#    'start_angle': -999999.0,
#    'end_angle': -999999.0,
#    'ang_reso': 1.0,
#    'scan_speed': 18.600000381469727,
#    'ref_reso': 250,
#    'vel_reso': 250,
#    'max_range1': 460000,
#    'max_range2': 2147483648,
#    'start_range': 0,
#    'sample_num1': 17,
#    'sample_num2': 2147483648,
#    'phase_mode': 0,
#    'atmo_loss': 0.010999999940395355,
#    'nyquist': 8.526031494140625,
#    'mom_mask': 3.2382e-319,
#    'mom_size_mask': 0.0,
#    'mgk_fil_mask': 62,
#    'sqi_thr': 0.15000000596046448,
#    'sig_thr': 5.0,
#    'csr_thr': 0.0,
#    'log_thr': 3.0,
#    'cpa_thr': 0.0,
#    'pmi_thr': 0.44999998807907104,
#    'dplog_thr': 5.0,
#    'thr_reserved': b'\x00\x00\x00\x00',
#    'dbt_mask': 1,
#    'dbz_mask': 1,
#    'vel_mask': 1,
#    'sw_mask': 1,
#    'dp_mask': 32,
#    'mask_reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#    'scan_sync': 0,
#    'direction': 1,
#    'grd_clutter_clsify': 3,
#    'grd_clutter_filt': 1,
#    'grd_clutter_filt_ntwidth': 3,
#    'grd_clutter_filt_window': 1,
#    'reserved': b''},
#   {'process_mod': 1,
#    'wave_form': 1,
#    'prf1': 1014.0,
#    'prf2': -999999.0,
#    'dias_mode': 1,
#    'azimuth': -999999.0,
#    'elevation': 0.4833984375,
#    'start_angle': -999999.0,
#    'end_angle': -999999.0,
#    'ang_reso': 1.0,
#    'scan_speed': 19.200000762939453,
#    'ref_reso': 250,
#    'vel_reso': 250,
#    'max_range1': 230000,
#    'max_range2': 2147483648,
#    'start_range': 0,
#    'sample_num1': 52,
#    'sample_num2': 2147483648,
#    'phase_mode': 0,
#    'atmo_loss': 0.010999999940395355,
#    'nyquist': 26.84905433654785,
#    'mom_mask': 1.2e-322,
#    'mom_size_mask': 0.0,
#    'mgk_fil_mask': 62,
#    'sqi_thr': 0.15000000596046448,
#    'sig_thr': 5.0,
#    'csr_thr': 0.0,
#    'log_thr': 3.0,
#    'cpa_thr': 0.0,
#    'pmi_thr': 0.44999998807907104,
#    'dplog_thr': 5.0,
#    'thr_reserved': b'\x00\x00\x00\x00',
#    'dbt_mask': 1,
#    'dbz_mask': 1,
#    'vel_mask': 1,
#    'sw_mask': 1,
#    'dp_mask': 32,
#    'mask_reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#    'scan_sync': 0,
#    'direction': 0,
#    'grd_clutter_clsify': 3,
#    'grd_clutter_filt': 1,
#    'grd_clutter_filt_ntwidth': 3,
#    'grd_clutter_filt_window': 1,
#    'reserved': b''},
#   {'process_mod': 1,
#    'wave_form': 0,
#    'prf1': 322.0,
#    'prf2': -999999.0,
#    'dias_mode': 1,
#    'azimuth': -999999.0,
#    'elevation': 1.494140625,
#    'start_angle': -999999.0,
#    'end_angle': -999999.0,
#    'ang_reso': 1.0,
#    'scan_speed': 19.799999237060547,
#    'ref_reso': 250,
#    'vel_reso': 250,
#    'max_range1': 460000,
#    'max_range2': 2147483648,
#    'start_range': 0,
#    'sample_num1': 16,
#    'sample_num2': 2147483648,
#    'phase_mode': 0,
#    'atmo_loss': 0.010999999940395355,
#    'nyquist': 8.526031494140625,
#    'mom_mask': 3.2382e-319,
#    'mom_size_mask': 0.0,
#    'mgk_fil_mask': 62,
#    'sqi_thr': 0.15000000596046448,
#    'sig_thr': 5.0,
#    'csr_thr': 0.0,
#    'log_thr': 3.0,
#    'cpa_thr': 0.0,
#    'pmi_thr': 0.44999998807907104,
#    'dplog_thr': 5.0,
#    'thr_reserved': b'\x00\x00\x00\x00',
#    'dbt_mask': 1,
#    'dbz_mask': 1,
#    'vel_mask': 1,
#    'sw_mask': 1,
#    'dp_mask': 32,
#    'mask_reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#    'scan_sync': 0,
#    'direction': 0,
#    'grd_clutter_clsify': 3,
#    'grd_clutter_filt': 1,
#    'grd_clutter_filt_ntwidth': 3,
#    'grd_clutter_filt_window': 1,
#    'reserved': b''},
#   {'process_mod': 1,
#    'wave_form': 1,
#    'prf1': 1014.0,
#    'prf2': -999999.0,
#    'dias_mode': 1,
#    'azimuth': -999999.0,
#    'elevation': 1.494140625,
#    'start_angle': -999999.0,
#    'end_angle': -999999.0,
#    'ang_reso': 1.0,
#    'scan_speed': 19.799999237060547,
#    'ref_reso': 250,
#    'vel_reso': 250,
#    'max_range1': 230000,
#    'max_range2': 2147483648,
#    'start_range': 0,
#    'sample_num1': 51,
#    'sample_num2': 2147483648,
#    'phase_mode': 0,
#    'atmo_loss': 0.010999999940395355,
#    'nyquist': 26.84905433654785,
#    'mom_mask': 1.2e-322,
#    'mom_size_mask': 0.0,
#    'mgk_fil_mask': 62,
#    'sqi_thr': 0.15000000596046448,
#    'sig_thr': 5.0,
#    'csr_thr': 0.0,
#    'log_thr': 3.0,
#    'cpa_thr': 0.0,
#    'pmi_thr': 0.44999998807907104,
#    'dplog_thr': 5.0,
#    'thr_reserved': b'\x00\x00\x00\x00',
#    'dbt_mask': 1,
#    'dbz_mask': 1,
#    'vel_mask': 1,
#    'sw_mask': 1,
#    'dp_mask': 32,
#    'mask_reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#    'scan_sync': 0,
#    'direction': 0,
#    'grd_clutter_clsify': 3,
#    'grd_clutter_filt': 1,
#    'grd_clutter_filt_ntwidth': 3,
#    'grd_clutter_filt_window': 1,
#    'reserved': b''},
#   {'process_mod': 1,
#    'wave_form': 4,
#    'prf1': 1014.0,
#    'prf2': 322.0,
#    'dias_mode': 1,
#    'azimuth': -999999.0,
#    'elevation': 2.4169921875,
#    'start_angle': -999999.0,
#    'end_angle': -999999.0,
#    'ang_reso': 1.0,
#    'scan_speed': 16.100000381469727,
#    'ref_reso': 250,
#    'vel_reso': 250,
#    'max_range1': 230000,
#    'max_range2': 330000,
#    'start_range': 0,
#    'sample_num1': 44,
#    'sample_num2': 6,
#    'phase_mode': 0,
#    'atmo_loss': 0.010999999940395355,
#    'nyquist': 26.84905433654785,
#    'mom_mask': 3.2394e-319,
#    'mom_size_mask': 0.0,
#    'mgk_fil_mask': 62,
#    'sqi_thr': 0.15000000596046448,
#    'sig_thr': 5.0,
#    'csr_thr': 60.0,
#    'log_thr': 3.0,
#    'cpa_thr': 0.0,
#    'pmi_thr': 0.44999998807907104,
#    'dplog_thr': 5.0,
#    'thr_reserved': b'\x00\x00\x00\x00',
#    'dbt_mask': 1,
#    'dbz_mask': 1,
#    'vel_mask': 1,
#    'sw_mask': 1,
#    'dp_mask': 32,
#    'mask_reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#    'scan_sync': 0,
#    'direction': 0,
#    'grd_clutter_clsify': 3,
#    'grd_clutter_filt': 1,
#    'grd_clutter_filt_ntwidth': 3,
#    'grd_clutter_filt_window': 1,
#    'reserved': b''},
#   {'process_mod': 1,
#    'wave_form': 4,
#    'prf1': 1014.0,
#    'prf2': 446.0,
#    'dias_mode': 1,
#    'azimuth': -999999.0,
#    'elevation': 3.299999952316284,
#    'start_angle': -999999.0,
#    'end_angle': -999999.0,
#    'ang_reso': 1.0,
#    'scan_speed': 20.0,
#    'ref_reso': 250,
#    'vel_reso': 250,
#    'max_range1': 230000,
#    'max_range2': 330000,
#    'start_range': 0,
#    'sample_num1': 34,
#    'sample_num2': 7,
#    'phase_mode': 0,
#    'atmo_loss': 0.010999999940395355,
#    'nyquist': 26.84905433654785,
#    'mom_mask': 3.2394e-319,
#    'mom_size_mask': 0.0,
#    'mgk_fil_mask': 4223,
#    'sqi_thr': 0.15000000596046448,
#    'sig_thr': 5.0,
#    'csr_thr': 60.0,
#    'log_thr': 3.0,
#    'cpa_thr': 0.0,
#    'pmi_thr': 0.44999998807907104,
#    'dplog_thr': 5.0,
#    'thr_reserved': b'\x00\x00\x00\x00',
#    'dbt_mask': 1,
#    'dbz_mask': 1,
#    'vel_mask': 1,
#    'sw_mask': 1,
#    'dp_mask': 32,
#    'mask_reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#    'scan_sync': 0,
#    'direction': 0,
#    'grd_clutter_clsify': 3,
#    'grd_clutter_filt': 1,
#    'grd_clutter_filt_ntwidth': 3,
#    'grd_clutter_filt_window': 1,
#    'reserved': b''},
#   {'process_mod': 1,
#    'wave_form': 4,
#    'prf1': 1014.0,
#    'prf2': 446.0,
#    'dias_mode': 1,
#    'azimuth': -999999.0,
#    'elevation': 4.309999942779541,
#    'start_angle': -999999.0,
#    'end_angle': -999999.0,
#    'ang_reso': 1.0,
#    'scan_speed': 20.0,
#    'ref_reso': 250,
#    'vel_reso': 250,
#    'max_range1': 230000,
#    'max_range2': 330000,
#    'start_range': 0,
#    'sample_num1': 34,
#    'sample_num2': 7,
#    'phase_mode': 0,
#    'atmo_loss': 0.010999999940395355,
#    'nyquist': 26.84905433654785,
#    'mom_mask': 3.2394e-319,
#    'mom_size_mask': 0.0,
#    'mgk_fil_mask': 4223,
#    'sqi_thr': 0.15000000596046448,
#    'sig_thr': 5.0,
#    'csr_thr': 60.0,
#    'log_thr': 3.0,
#    'cpa_thr': 0.0,
#    'pmi_thr': 0.44999998807907104,
#    'dplog_thr': 5.0,
#    'thr_reserved': b'\x00\x00\x00\x00',
#    'dbt_mask': 1,
#    'dbz_mask': 1,
#    'vel_mask': 1,
#    'sw_mask': 1,
#    'dp_mask': 32,
#    'mask_reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#    'scan_sync': 0,
#    'direction': 0,
#    'grd_clutter_clsify': 3,
#    'grd_clutter_filt': 1,
#    'grd_clutter_filt_ntwidth': 3,
#    'grd_clutter_filt_window': 1,
#    'reserved': b''},
#   {'process_mod': 1,
#    'wave_form': 4,
#    'prf1': 1014.0,
#    'prf2': 644.0,
#    'dias_mode': 1,
#    'azimuth': -999999.0,
#    'elevation': 5.320000171661377,
#    'start_angle': -999999.0,
#    'end_angle': -999999.0,
#    'ang_reso': 1.0,
#    'scan_speed': 20.0,
#    'ref_reso': 250,
#    'vel_reso': 250,
#    'max_range1': 230000,
#    'max_range2': 228670,
#    'start_range': 0,
#    'sample_num1': 36,
#    'sample_num2': 9,
#    'phase_mode': 0,
#    'atmo_loss': 0.010999999940395355,
#    'nyquist': 26.84905433654785,
#    'mom_mask': 3.2394e-319,
#    'mom_size_mask': 0.0,
#    'mgk_fil_mask': 62,
#    'sqi_thr': 0.15000000596046448,
#    'sig_thr': 5.0,
#    'csr_thr': 60.0,
#    'log_thr': 3.0,
#    'cpa_thr': 0.0,
#    'pmi_thr': 0.44999998807907104,
#    'dplog_thr': 5.0,
#    'thr_reserved': b'\x00\x00\x00\x00',
#    'dbt_mask': 1,
#    'dbz_mask': 1,
#    'vel_mask': 1,
#    'sw_mask': 1,
#    'dp_mask': 32,
#    'mask_reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#    'scan_sync': 0,
#    'direction': 0,
#    'grd_clutter_clsify': 3,
#    'grd_clutter_filt': 1,
#    'grd_clutter_filt_ntwidth': 3,
#    'grd_clutter_filt_window': 1,
#    'reserved': b''},
#   {'process_mod': 1,
#    'wave_form': 4,
#    'prf1': 1014.0,
#    'prf2': 644.0,
#    'dias_mode': 1,
#    'azimuth': -999999.0,
#    'elevation': 6.199999809265137,
#    'start_angle': -999999.0,
#    'end_angle': -999999.0,
#    'ang_reso': 1.0,
#    'scan_speed': 20.0,
#    'ref_reso': 250,
#    'vel_reso': 250,
#    'max_range1': 230000,
#    'max_range2': 228670,
#    'start_range': 0,
#    'sample_num1': 36,
#    'sample_num2': 9,
#    'phase_mode': 0,
#    'atmo_loss': 0.010999999940395355,
#    'nyquist': 26.84905433654785,
#    'mom_mask': 3.2394e-319,
#    'mom_size_mask': 0.0,
#    'mgk_fil_mask': 62,
#    'sqi_thr': 0.15000000596046448,
#    'sig_thr': 5.0,
#    'csr_thr': 60.0,
#    'log_thr': 3.0,
#    'cpa_thr': 0.0,
#    'pmi_thr': 0.44999998807907104,
#    'dplog_thr': 5.0,
#    'thr_reserved': b'\x00\x00\x00\x00',
#    'dbt_mask': 1,
#    'dbz_mask': 1,
#    'vel_mask': 1,
#    'sw_mask': 1,
#    'dp_mask': 32,
#    'mask_reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#    'scan_sync': 0,
#    'direction': 0,
#    'grd_clutter_clsify': 3,
#    'grd_clutter_filt': 1,
#    'grd_clutter_filt_ntwidth': 3,
#    'grd_clutter_filt_window': 1,
#    'reserved': b''},
#   {'process_mod': 1,
#    'wave_form': 2,
#    'prf1': 1181.0,
#    'prf2': -999999.0,
#    'dias_mode': 1,
#    'azimuth': -999999.0,
#    'elevation': 7.470703125,
#    'start_angle': -999999.0,
#    'end_angle': -999999.0,
#    'ang_reso': 1.0,
#    'scan_speed': 25.5,
#    'ref_reso': 250,
#    'vel_reso': 250,
#    'max_range1': 124000,
#    'max_range2': 2147483648,
#    'start_range': 0,
#    'sample_num1': 46,
#    'sample_num2': 2147483648,
#    'phase_mode': 0,
#    'atmo_loss': 0.010999999940395355,
#    'nyquist': 31.27094078063965,
#    'mom_mask': 3.2394e-319,
#    'mom_size_mask': 0.0,
#    'mgk_fil_mask': 62,
#    'sqi_thr': 0.15000000596046448,
#    'sig_thr': 5.0,
#    'csr_thr': 60.0,
#    'log_thr': 3.0,
#    'cpa_thr': 0.0,
#    'pmi_thr': 0.44999998807907104,
#    'dplog_thr': 5.0,
#    'thr_reserved': b'\x00\x00\x00\x00',
#    'dbt_mask': 1,
#    'dbz_mask': 1,
#    'vel_mask': 1,
#    'sw_mask': 1,
#    'dp_mask': 32,
#    'mask_reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#    'scan_sync': 0,
#    'direction': 0,
#    'grd_clutter_clsify': 3,
#    'grd_clutter_filt': 1,
#    'grd_clutter_filt_ntwidth': 3,
#    'grd_clutter_filt_window': 1,
#    'reserved': b''},
#   {'process_mod': 1,
#    'wave_form': 2,
#    'prf1': 1181.0,
#    'prf2': -999999.0,
#    'dias_mode': 1,
#    'azimuth': -999999.0,
#    'elevation': 8.701171875,
#    'start_angle': -999999.0,
#    'end_angle': -999999.0,
#    'ang_reso': 1.0,
#    'scan_speed': 25.5,
#    'ref_reso': 250,
#    'vel_reso': 250,
#    'max_range1': 124000,
#    'max_range2': 2147483648,
#    'start_range': 0,
#    'sample_num1': 46,
#    'sample_num2': 2147483648,
#    'phase_mode': 0,
#    'atmo_loss': 0.010999999940395355,
#    'nyquist': 31.27094078063965,
#    'mom_mask': 3.2394e-319,
#    'mom_size_mask': 0.0,
#    'mgk_fil_mask': 62,
#    'sqi_thr': 0.15000000596046448,
#    'sig_thr': 5.0,
#    'csr_thr': 60.0,
#    'log_thr': 3.0,
#    'cpa_thr': 0.0,
#    'pmi_thr': 0.44999998807907104,
#    'dplog_thr': 5.0,
#    'thr_reserved': b'\x00\x00\x00\x00',
#    'dbt_mask': 1,
#    'dbz_mask': 1,
#    'vel_mask': 1,
#    'sw_mask': 1,
#    'dp_mask': 32,
#    'mask_reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#    'scan_sync': 0,
#    'direction': 0,
#    'grd_clutter_clsify': 3,
#    'grd_clutter_filt': 1,
#    'grd_clutter_filt_ntwidth': 3,
#    'grd_clutter_filt_window': 1,
#    'reserved': b''},
#   {'process_mod': 1,
#    'wave_form': 2,
#    'prf1': 1181.0,
#    'prf2': -999999.0,
#    'dias_mode': 1,
#    'azimuth': -999999.0,
#    'elevation': 10.01953125,
#    'start_angle': -999999.0,
#    'end_angle': -999999.0,
#    'ang_reso': 1.0,
#    'scan_speed': 25.5,
#    'ref_reso': 250,
#    'vel_reso': 250,
#    'max_range1': 124000,
#    'max_range2': 2147483648,
#    'start_range': 0,
#    'sample_num1': 46,
#    'sample_num2': 2147483648,
#    'phase_mode': 0,
#    'atmo_loss': 0.010999999940395355,
#    'nyquist': 31.27094078063965,
#    'mom_mask': 3.2394e-319,
#    'mom_size_mask': 0.0,
#    'mgk_fil_mask': 62,
#    'sqi_thr': 0.15000000596046448,
#    'sig_thr': 5.0,
#    'csr_thr': 60.0,
#    'log_thr': 3.0,
#    'cpa_thr': 0.0,
#    'pmi_thr': 0.44999998807907104,
#    'dplog_thr': 5.0,
#    'thr_reserved': b'\x00\x00\x00\x00',
#    'dbt_mask': 1,
#    'dbz_mask': 1,
#    'vel_mask': 1,
#    'sw_mask': 1,
#    'dp_mask': 32,
#    'mask_reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#    'scan_sync': 0,
#    'direction': 0,
#    'grd_clutter_clsify': 3,
#    'grd_clutter_filt': 1,
#    'grd_clutter_filt_ntwidth': 3,
#    'grd_clutter_filt_window': 1,
#    'reserved': b''},
#   {'process_mod': 1,
#    'wave_form': 2,
#    'prf1': 1181.0,
#    'prf2': -999999.0,
#    'dias_mode': 1,
#    'azimuth': -999999.0,
#    'elevation': 11.9970703125,
#    'start_angle': -999999.0,
#    'end_angle': -999999.0,
#    'ang_reso': 1.0,
#    'scan_speed': 25.5,
#    'ref_reso': 250,
#    'vel_reso': 250,
#    'max_range1': 124000,
#    'max_range2': 2147483648,
#    'start_range': 0,
#    'sample_num1': 46,
#    'sample_num2': 2147483648,
#    'phase_mode': 0,
#    'atmo_loss': 0.010999999940395355,
#    'nyquist': 31.27094078063965,
#    'mom_mask': 3.2394e-319,
#    'mom_size_mask': 0.0,
#    'mgk_fil_mask': 62,
#    'sqi_thr': 0.15000000596046448,
#    'sig_thr': 5.0,
#    'csr_thr': 60.0,
#    'log_thr': 3.0,
#    'cpa_thr': 0.0,
#    'pmi_thr': 0.44999998807907104,
#    'dplog_thr': 5.0,
#    'thr_reserved': b'\x00\x00\x00\x00',
#    'dbt_mask': 1,
#    'dbz_mask': 1,
#    'vel_mask': 1,
#    'sw_mask': 1,
#    'dp_mask': 32,
#    'mask_reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#    'scan_sync': 0,
#    'direction': 0,
#    'grd_clutter_clsify': 3,
#    'grd_clutter_filt': 1,
#    'grd_clutter_filt_ntwidth': 3,
#    'grd_clutter_filt_window': 1,
#    'reserved': b''},
#   {'process_mod': 1,
#    'wave_form': 2,
#    'prf1': 1181.0,
#    'prf2': -999999.0,
#    'dias_mode': 1,
#    'azimuth': -999999.0,
#    'elevation': 14.0185546875,
#    'start_angle': -999999.0,
#    'end_angle': -999999.0,
#    'ang_reso': 1.0,
#    'scan_speed': 25.5,
#    'ref_reso': 250,
#    'vel_reso': 250,
#    'max_range1': 124000,
#    'max_range2': 2147483648,
#    'start_range': 0,
#    'sample_num1': 46,
#    'sample_num2': 2147483648,
#    'phase_mode': 0,
#    'atmo_loss': 0.010999999940395355,
#    'nyquist': 31.27094078063965,
#    'mom_mask': 3.2394e-319,
#    'mom_size_mask': 0.0,
#    'mgk_fil_mask': 62,
#    'sqi_thr': 0.15000000596046448,
#    'sig_thr': 5.0,
#    'csr_thr': 60.0,
#    'log_thr': 3.0,
#    'cpa_thr': 0.0,
#    'pmi_thr': 0.44999998807907104,
#    'dplog_thr': 5.0,
#    'thr_reserved': b'\x00\x00\x00\x00',
#    'dbt_mask': 1,
#    'dbz_mask': 1,
#    'vel_mask': 1,
#    'sw_mask': 1,
#    'dp_mask': 32,
#    'mask_reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#    'scan_sync': 0,
#    'direction': 0,
#    'grd_clutter_clsify': 3,
#    'grd_clutter_filt': 1,
#    'grd_clutter_filt_ntwidth': 3,
#    'grd_clutter_filt_window': 1,
#    'reserved': b''},
#   {'process_mod': 1,
#    'wave_form': 2,
#    'prf1': 1181.0,
#    'prf2': -999999.0,
#    'dias_mode': 1,
#    'azimuth': -999999.0,
#    'elevation': 16.69921875,
#    'start_angle': -999999.0,
#    'end_angle': -999999.0,
#    'ang_reso': 1.0,
#    'scan_speed': 25.5,
#    'ref_reso': 250,
#    'vel_reso': 250,
#    'max_range1': 124000,
#    'max_range2': 2147483648,
#    'start_range': 0,
#    'sample_num1': 46,
#    'sample_num2': 2147483648,
#    'phase_mode': 0,
#    'atmo_loss': 0.010999999940395355,
#    'nyquist': 31.27094078063965,
#    'mom_mask': 3.2394e-319,
#    'mom_size_mask': 0.0,
#    'mgk_fil_mask': 62,
#    'sqi_thr': 0.15000000596046448,
#    'sig_thr': 5.0,
#    'csr_thr': 60.0,
#    'log_thr': 3.0,
#    'cpa_thr': 0.0,
#    'pmi_thr': 0.44999998807907104,
#    'dplog_thr': 5.0,
#    'thr_reserved': b'\x00\x00\x00\x00',
#    'dbt_mask': 1,
#    'dbz_mask': 1,
#    'vel_mask': 1,
#    'sw_mask': 1,
#    'dp_mask': 32,
#    'mask_reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#    'scan_sync': 0,
#    'direction': 0,
#    'grd_clutter_clsify': 3,
#    'grd_clutter_filt': 1,
#    'grd_clutter_filt_ntwidth': 3,
#    'grd_clutter_filt_window': 1,
#    'reserved': b''},
#   {'process_mod': 1,
#    'wave_form': 2,
#    'prf1': 1181.0,
#    'prf2': -999999.0,
#    'dias_mode': 1,
#    'azimuth': -999999.0,
#    'elevation': 19.51171875,
#    'start_angle': -999999.0,
#    'end_angle': -999999.0,
#    'ang_reso': 1.0,
#    'scan_speed': 25.5,
#    'ref_reso': 250,
#    'vel_reso': 250,
#    'max_range1': 124000,
#    'max_range2': 2147483648,
#    'start_range': 0,
#    'sample_num1': 46,
#    'sample_num2': 2147483648,
#    'phase_mode': 0,
#    'atmo_loss': 0.010999999940395355,
#    'nyquist': 31.27094078063965,
#    'mom_mask': 3.2394e-319,
#    'mom_size_mask': 0.0,
#    'mgk_fil_mask': 62,
#    'sqi_thr': 0.15000000596046448,
#    'sig_thr': 5.0,
#    'csr_thr': 60.0,
#    'log_thr': 3.0,
#    'cpa_thr': 0.0,
#    'pmi_thr': 0.44999998807907104,
#    'dplog_thr': 5.0,
#    'thr_reserved': b'\x00\x00\x00\x00',
#    'dbt_mask': 1,
#    'dbz_mask': 1,
#    'vel_mask': 1,
#    'sw_mask': 1,
#    'dp_mask': 32,
#    'mask_reserved': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#    'scan_sync': 0,
#    'direction': 0,
#    'grd_clutter_clsify': 3,
#    'grd_clutter_filt': 1,
#    'grd_clutter_filt_ntwidth': 3,
#    'grd_clutter_filt_window': 1,
#    'reserved': b''}],
#  'dic_prod_header': {'product_type': 37,
#   'product_name': b'58\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00',
#   'product_time_ms': 1760175461,
#   'scan_start_ms': 1746707520,
#   'data_start_ms': 1746707520,
#   'data_end_ms': 1746707854,
#   'project_type': 2,
#   'data_type1': 2,
#   'data_type2': 0,
#   'reserved': b''},
#  'dic_prod_param': {'max_range': 345000},
#  'dic_sti_header': {'storm_number': 38,
#   'con_storm_number': 32,
#   'component_number': 198,
#   'storm_speed_ave': 10.42527961730957,
#   'storm_dir_ave': 274.583251953125},
#  'storm_motion_block': [{'azi': 278.80078125,
#    'range': 93604,
#    'mv_spd': 18.94475746154785,
#    'mv_dir': 295.5546875,
#    'forecast_error': 2349,
#    'mean_forecast_error': 2799,
#    'lon': np.float64(106.58960795900846),
#    'lat': np.float64(25.115412606232596)},
#   {'azi': 275.448974609375,
#    'range': 172132,
#    'mv_spd': 13.14350700378418,
#    'mv_dir': 309.5078125,
#    'forecast_error': 861,
#    'mean_forecast_error': 2635,
#    'lon': np.float64(105.80642733315258),
#    'lat': np.float64(25.12673885979999)},
#   {'azi': 284.42352294921875,
#    'range': 138711,
#    'mv_spd': 10.407597541809082,
#    'mv_dir': 286.8023681640625,
#    'forecast_error': 2318,
#    'mean_forecast_error': 2703,
#    'lon': np.float64(106.1721828246575),
#    'lat': np.float64(25.294170026078174)},
#   {'azi': 227.41697692871094,
#    'range': 23519,
#    'mv_spd': 13.81373119354248,
#    'mv_dir': 341.5098571777344,
#    'forecast_error': 3149,
#    'mean_forecast_error': 3136,
#    'lon': np.float64(107.33671098189464),
#    'lat': np.float64(24.846225796463372)},
#   {'azi': 105.7766342163086,
#    'range': 30401,
#    'mv_spd': 9.40675163269043,
#    'mv_dir': 299.333251953125,
#    'forecast_error': 1294,
#    'mean_forecast_error': 1294,
#    'lon': np.float64(107.79843203955167),
#    'lat': np.float64(24.91482901218026)},
#   {'azi': 225.35731506347656,
#    'range': 29856,
#    'mv_spd': 12.528234481811523,
#    'mv_dir': 299.32171630859375,
#    'forecast_error': 2912,
#    'mean_forecast_error': 4076,
#    'lon': np.float64(107.29788377305752),
#    'lat': np.float64(24.800626061442586)},
#   {'azi': 85.54539489746094,
#    'range': 27051,
#    'mv_spd': 13.999850273132324,
#    'mv_dir': 290.46026611328125,
#    'forecast_error': 3488,
#    'mean_forecast_error': 2393,
#    'lon': np.float64(107.77596227479252),
#    'lat': np.float64(25.008100339182892)},
#   {'azi': 84.36976623535156,
#    'range': 17006,
#    'mv_spd': 22.79365348815918,
#    'mv_dir': 285.1807556152344,
#    'forecast_error': 9698,
#    'mean_forecast_error': 6926,
#    'lon': np.float64(107.67627217264157),
#    'lat': np.float64(25.004354980825333)},
#   {'azi': 280.6893310546875,
#    'range': 154098,
#    'mv_spd': 12.158143997192383,
#    'mv_dir': 281.2663879394531,
#    'forecast_error': 4653,
#    'mean_forecast_error': 1739,
#    'lon': np.float64(106.00296161942234),
#    'lat': np.float64(25.238886065712382)},
#   {'azi': 291.9075927734375,
#    'range': 125897,
#    'mv_spd': 20.136743545532227,
#    'mv_dir': 293.53656005859375,
#    'forecast_error': 3511,
#    'mean_forecast_error': 3250,
#    'lon': np.float64(106.34547518609314),
#    'lat': np.float64(25.407330447100662)},
#   {'azi': 74.37786102294922,
#    'range': 75327,
#    'mv_spd': 2.046894073486328,
#    'mv_dir': 236.90512084960938,
#    'forecast_error': 4661,
#    'mean_forecast_error': 4090,
#    'lon': np.float64(108.22916738252577),
#    'lat': np.float64(25.170129419342857)},
#   {'azi': 91.17333984375,
#    'range': 208119,
#    'mv_spd': 21.17169189453125,
#    'mv_dir': 277.5291442871094,
#    'forecast_error': 4310,
#    'mean_forecast_error': 4310,
#    'lon': np.float64(109.57165452637491),
#    'lat': np.float64(24.93690265579285)},
#   {'azi': 108.91486358642578,
#    'range': 185778,
#    'mv_spd': 5.612240314483643,
#    'mv_dir': 287.8911437988281,
#    'forecast_error': 822,
#    'mean_forecast_error': 2138,
#    'lon': np.float64(109.24413173848139),
#    'lat': np.float64(24.437894845707252)},
#   {'azi': 106.94145202636719,
#    'range': 19625,
#    'mv_spd': 18.382518768310547,
#    'mv_dir': 295.9279479980469,
#    'forecast_error': 5613,
#    'mean_forecast_error': 5908,
#    'lon': np.float64(107.69452331433955),
#    'lat': np.float64(24.937900253853094)},
#   {'azi': 81.8488540649414,
#    'range': 96144,
#    'mv_spd': 7.34025239944458,
#    'mv_dir': 318.70440673828125,
#    'forecast_error': 1289,
#    'mean_forecast_error': 1676,
#    'lon': np.float64(108.45352972115802),
#    'lat': np.float64(25.109046163283665)},
#   {'azi': 79.08042907714844,
#    'range': 100628,
#    'mv_spd': 9.025664329528809,
#    'mv_dir': 292.685791015625,
#    'forecast_error': 3489,
#    'mean_forecast_error': 2389,
#    'lon': np.float64(108.49000029949998),
#    'lat': np.float64(25.157643433901786)},
#   {'azi': 89.29173278808594,
#    'range': 55723,
#    'mv_spd': 5.178269863128662,
#    'mv_dir': 206.96026611328125,
#    'forecast_error': 484,
#    'mean_forecast_error': 2292,
#    'lon': np.float64(108.06119334836112),
#    'lat': np.float64(24.994617873726266)},
#   {'azi': 70.95120239257812,
#    'range': 94368,
#    'mv_spd': 15.984817504882812,
#    'mv_dir': 241.07760620117188,
#    'forecast_error': 3993,
#    'mean_forecast_error': 2854,
#    'lon': np.float64(108.39534101693611),
#    'lat': np.float64(25.263785153720363)},
#   {'azi': 77.87834167480469,
#    'range': 116762,
#    'mv_spd': 9.512654304504395,
#    'mv_dir': 287.74127197265625,
#    'forecast_error': 2876,
#    'mean_forecast_error': 2461,
#    'lon': np.float64(108.64296411515511),
#    'lat': np.float64(25.205626487447038)},
#   {'azi': 83.66592407226562,
#    'range': 66763,
#    'mv_spd': 17.22899055480957,
#    'mv_dir': 227.600830078125,
#    'forecast_error': 2565,
#    'mean_forecast_error': 4044,
#    'lon': np.float64(108.1670510754327),
#    'lat': np.float64(25.054234027565563)},
#   {'azi': 68.27226257324219,
#    'range': 63215,
#    'mv_spd': 3.5450072288513184,
#    'mv_dir': 189.63214111328125,
#    'forecast_error': 2251,
#    'mean_forecast_error': 3909,
#    'lon': np.float64(108.09198024288557),
#    'lat': np.float64(25.19876065469363)},
#   {'azi': 88.06449127197266,
#    'range': 263786,
#    'mv_spd': 29.10525131225586,
#    'mv_dir': 234.51185607910156,
#    'forecast_error': 8219,
#    'mean_forecast_error': 8219,
#    'lon': np.float64(110.12468169378234),
#    'lat': np.float64(25.0466604030195)},
#   {'azi': 12.890445709228516,
#    'range': 46897,
#    'mv_spd': 8.962681770324707,
#    'mv_dir': 272.4742736816406,
#    'forecast_error': 738,
#    'mean_forecast_error': 1890,
#    'lon': np.float64(107.61248638870309),
#    'lat': np.float64(25.40053039672606)},
#   {'azi': 86.48677825927734,
#    'range': 81693,
#    'mv_spd': 8.284439086914062,
#    'mv_dir': 233.52566528320312,
#    'forecast_error': 1271,
#    'mean_forecast_error': 1539,
#    'lon': np.float64(108.31763352467004),
#    'lat': np.float64(25.032274907789418)},
#   {'azi': 274.880859375,
#    'range': 103244,
#    'mv_spd': 10.42527961730957,
#    'mv_dir': 274.583251953125,
#    'forecast_error': 0,
#    'mean_forecast_error': 0,
#    'lon': np.float64(106.48706461659148),
#    'lat': np.float64(25.064954766762938)},
#   {'azi': 154.83177185058594,
#    'range': 7153,
#    'mv_spd': 5.897358417510986,
#    'mv_dir': 299.1922302246094,
#    'forecast_error': 1141,
#    'mean_forecast_error': 3641,
#    'lon': np.float64(107.53850004293945),
#    'lat': np.float64(24.93122035529446)},
#   {'azi': 289.6528625488281,
#    'range': 101143,
#    'mv_spd': 10.42527961730957,
#    'mv_dir': 274.583251953125,
#    'forecast_error': 0,
#    'mean_forecast_error': 0,
#    'lon': np.float64(106.56093631347268),
#    'lat': np.float64(25.292344825213657)},
#   {'azi': 69.60863494873047,
#    'range': 118275,
#    'mv_spd': 7.048309803009033,
#    'mv_dir': 273.92340087890625,
#    'forecast_error': 3636,
#    'mean_forecast_error': 2840,
#    'lon': np.float64(108.61156955213633),
#    'lat': np.float64(25.35596378825359)},
#   {'azi': 86.54585266113281,
#    'range': 186866,
#    'mv_spd': 14.755123138427734,
#    'mv_dir': 256.0906677246094,
#    'forecast_error': 5314,
#    'mean_forecast_error': 3005,
#    'lon': np.float64(109.36017337071934),
#    'lat': np.float64(25.0792156672782)},
#   {'azi': 285.1464538574219,
#    'range': 13321,
#    'mv_spd': 22.135080337524414,
#    'mv_dir': 278.2412414550781,
#    'forecast_error': 4652,
#    'mean_forecast_error': 4652,
#    'lon': np.float64(107.3807185647867),
#    'lat': np.float64(25.020692147658707)},
#   {'azi': 122.23287963867188,
#    'range': 19139,
#    'mv_spd': 10.42527961730957,
#    'mv_dir': 274.583251953125,
#    'forecast_error': 0,
#    'mean_forecast_error': 0,
#    'lon': np.float64(107.6688439112457),
#    'lat': np.float64(24.897555938819625)},
#   {'azi': 271.69287109375,
#    'range': 48657,
#    'mv_spd': 10.42527961730957,
#    'mv_dir': 274.583251953125,
#    'forecast_error': 0,
#    'mean_forecast_error': 0,
#    'lon': np.float64(107.02572048068743),
#    'lat': np.float64(25.001593301896815)},
#   {'azi': 17.482789993286133,
#    'range': 8539,
#    'mv_spd': 8.386955261230469,
#    'mv_dir': 187.61143493652344,
#    'forecast_error': 4313,
#    'mean_forecast_error': 4313,
#    'lon': np.float64(107.5337993678239),
#    'lat': np.float64(25.06268836175304)},
#   {'azi': 298.4501953125,
#    'range': 120863,
#    'mv_spd': 10.42527961730957,
#    'mv_dir': 274.583251953125,
#    'forecast_error': 0,
#    'mean_forecast_error': 0,
#    'lon': np.float64(106.44955176247908),
#    'lat': np.float64(25.503471755255546)},
#   {'azi': 72.8608169555664,
#    'range': 104360,
#    'mv_spd': 7.187609672546387,
#    'mv_dir': 272.2137451171875,
#    'forecast_error': 7473,
#    'mean_forecast_error': 5689,
#    'lon': np.float64(108.499986155324),
#    'lat': np.float64(25.26272077560556)},
#   {'azi': 338.5548400878906,
#    'range': 105482,
#    'mv_spd': 10.42527961730957,
#    'mv_dir': 274.583251953125,
#    'forecast_error': 0,
#    'mean_forecast_error': 0,
#    'lon': np.float64(107.12290550625654),
#    'lat': np.float64(25.871848887035778)},
#   {'azi': 57.40081787109375,
#    'range': 49319,
#    'mv_spd': 7.715335369110107,
#    'mv_dir': 215.64549255371094,
#    'forecast_error': 1598,
#    'mean_forecast_error': 1651,
#    'lon': np.float64(107.921385578448),
#    'lat': np.float64(25.227830607001266)},
#   {'azi': 50.24363708496094,
#    'range': 59303,
#    'mv_spd': 9.43014907836914,
#    'mv_dir': 263.2575988769531,
#    'forecast_error': 770,
#    'mean_forecast_error': 770,
#    'lon': np.float64(107.96193735209151),
#    'lat': np.float64(25.329824957492697)}],
#  'all_storm_fst_block': [[{'azi': 275.16180419921875,
#     'range': 77433,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(106.74279040005533),
#     'lat': np.float64(25.05013584688251)},
#    {'azi': 269.63934326171875,
#     'range': 61738,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(106.89580713130957),
#     'lat': np.float64(24.98469622893878)},
#    {'azi': 260.51629638671875,
#     'range': 46997,
#     'vol_time_position': 1746710220,
#     'lon': np.float64(107.04866371975851),
#     'lat': np.float64(24.91910010007766)}],
#   [{'azi': 273.1122131347656,
#     'range': 162467,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(105.89793211199814),
#     'lat': np.float64(25.060091959819843)},
#    {'azi': 270.484619140625,
#     'range': 153106,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(105.98934149832961),
#     'lat': np.float64(24.99337927657658)},
#    {'azi': 267.52191162109375,
#     'range': 144108,
#     'vol_time_position': 1746710220,
#     'lon': np.float64(106.08065891999854),
#     'lat': np.float64(24.926605661396724)},
#    {'azi': 264.1751708984375,
#     'range': 135547,
#     'vol_time_position': 1746711120,
#     'lon': np.float64(106.1718680949884),
#     'lat': np.float64(24.85977656357947)}],
#   [{'azi': 284.25152587890625,
#     'range': 129352,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(106.26160759335058),
#     'lat': np.float64(25.270600442719132)},
#    {'azi': 284.0524597167969,
#     'range': 119995,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(106.35099310303673),
#     'lat': np.float64(25.24697313989937)},
#    {'azi': 283.8197021484375,
#     'range': 110640,
#     'vol_time_position': 1746710220,
#     'lon': np.float64(106.44034351649111),
#     'lat': np.float64(25.22329153319199)}],
#   [{'azi': 205.76834106445312,
#     'range': 30764,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(107.37590033089786),
#     'lat': np.float64(24.74023190658874)},
#    {'azi': 193.43051147460938,
#     'range': 40605,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(107.41502383848753),
#     'lat': np.float64(24.634235222948913)}],
#   [{'azi': 108.71739196777344,
#     'range': 38682,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(107.871505684311),
#     'lat': np.float64(24.87737149358173)},
#    {'azi': 110.61787414550781,
#     'range': 47029,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(107.94453536299785),
#     'lat': np.float64(24.839878710310742)},
#    {'azi': 111.9444351196289,
#     'range': 55412,
#     'vol_time_position': 1746710220,
#     'lon': np.float64(108.01751882872114),
#     'lat': np.float64(24.802351334064227)},
#    {'azi': 112.92198181152344,
#     'range': 63817,
#     'vol_time_position': 1746711120,
#     'lon': np.float64(108.09045818202549),
#     'lat': np.float64(24.764788754261804)}],
#   [{'azi': 203.29754638671875,
#     'range': 28853,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(107.3953241166914),
#     'lat': np.float64(24.75107888700468)},
#    {'azi': 182.82638549804688,
#     'range': 32061,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(107.49268191352803),
#     'lat': np.float64(24.701464392155568)}],
#   [{'azi': 93.39964294433594,
#     'range': 38842,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(107.89297755860494),
#     'lat': np.float64(24.9682361295702)},
#    {'azi': 97.5544204711914,
#     'range': 51022,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(108.00992683190704),
#     'lat': np.float64(24.92828068726479)}],
#   [],
#   [{'azi': 280.6454162597656,
#     'range': 143156,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(106.10984256675366),
#     'lat': np.float64(25.22070850600728)}],
#   [{'azi': 291.6339416503906,
#     'range': 107782,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(106.51140339027859),
#     'lat': np.float64(25.343459140963716)},
#    {'azi': 291.24945068359375,
#     'range': 89671,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(106.67715847887797),
#     'lat': np.float64(25.279396619232458)}],
#   [{'azi': 73.9667739868164,
#     'range': 77086,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(108.2445543779882),
#     'lat': np.float64(25.179099215167064)}],
#   [{'azi': 91.70564270019531,
#     'range': 227066,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(109.75844389595396),
#     'lat': np.float64(24.91176456443216)}],
#   [{'azi': 108.88780975341797,
#     'range': 190828,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(109.29138471182793),
#     'lat': np.float64(24.42339289135914)},
#    {'azi': 108.86210632324219,
#     'range': 195878,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(109.3386256857117),
#     'lat': np.float64(24.40887806362754)},
#    {'azi': 108.83770751953125,
#     'range': 200928,
#     'vol_time_position': 1746710220,
#     'lon': np.float64(109.38585400297407),
#     'lat': np.float64(24.39434871393514)},
#    {'azi': 108.81449890136719,
#     'range': 205979,
#     'vol_time_position': 1746711120,
#     'lon': np.float64(109.43307917126833),
#     'lat': np.float64(24.379802403797253)}],
#   [{'azi': 111.0512466430664,
#     'range': 36058,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(107.84190521839244),
#     'lat': np.float64(24.87259240498831)}],
#   [{'azi': 85.02262878417969,
#     'range': 99909,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(108.49646122309682),
#     'lat': np.float64(25.06413365677353)},
#    {'azi': 87.95758819580078,
#     'range': 103958,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(108.53936264045069),
#     'lat': np.float64(25.01921024359719)},
#    {'azi': 90.66600036621094,
#     'range': 108259,
#     'vol_time_position': 1746710220,
#     'lon': np.float64(108.58223252541562),
#     'lat': np.float64(24.974275196360562)},
#    {'azi': 93.16234588623047,
#     'range': 112783,
#     'vol_time_position': 1746711120,
#     'lon': np.float64(108.62506916041657),
#     'lat': np.float64(24.929328653014007)}],
#   [{'azi': 81.4776840209961,
#     'range': 107487,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(108.56420354553127),
#     'lat': np.float64(25.12896243966336)},
#    {'azi': 83.58409118652344,
#     'range': 114512,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(108.63837583067327),
#     'lat': np.float64(25.100246966227324)}],
#   [{'azi': 85.21331787109375,
#     'range': 58034,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(108.08233143937422),
#     'lat': np.float64(25.031894539953502)},
#    {'azi': 81.4645767211914,
#     'range': 60615,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(108.103474424534),
#     'lat': np.float64(25.069167184052162)},
#    {'azi': 78.03543853759766,
#     'range': 63435,
#     'vol_time_position': 1746710220,
#     'lon': np.float64(108.12464258190835),
#     'lat': np.float64(25.106437981898395)},
#    {'azi': 74.90827178955078,
#     'range': 66462,
#     'vol_time_position': 1746711120,
#     'lon': np.float64(108.14581872740645),
#     'lat': np.float64(25.143704866369227)}],
#   [{'azi': 69.64926147460938,
#     'range': 108569,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(108.52105617304719),
#     'lat': np.float64(25.325547761771894)}],
#   [{'azi': 79.84439849853516,
#     'range': 124259,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(108.72375460531026),
#     'lat': np.float64(25.18152813968606)},
#    {'azi': 81.58486938476562,
#     'range': 131887,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(108.80452486099014),
#     'lat': np.float64(25.157389816582477)}],
#   [{'azi': 77.09912872314453,
#     'range': 79821,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(108.2813077975113),
#     'lat': np.float64(25.14771238492223)},
#    {'azi': 72.42163848876953,
#     'range': 93628,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(108.39572848896128),
#     'lat': np.float64(25.241097766573596)},
#    {'azi': 68.96308898925781,
#     'range': 107899,
#     'vol_time_position': 1746710220,
#     'lon': np.float64(108.51033692285613),
#     'lat': np.float64(25.334395380697764)}],
#   [{'azi': 65.86759185791016,
#     'range': 64932,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(108.09741700481764),
#     'lat': np.float64(25.22702446473461)},
#    {'azi': 63.590599060058594,
#     'range': 66758,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(108.10286192610934),
#     'lat': np.float64(25.255290369981058)},
#    {'azi': 61.43803024291992,
#     'range': 68684,
#     'vol_time_position': 1746710220,
#     'lon': np.float64(108.10831165405058),
#     'lat': np.float64(25.28355722946108)}],
#   [],
#   [{'azi': 22.20777130126953,
#     'range': 49001,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(107.69270812348634),
#     'lat': np.float64(25.397313504712994)},
#    {'azi': 30.558494567871094,
#     'range': 52279,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(107.7729277725936),
#     'lat': np.float64(25.39406205609589)},
#    {'azi': 37.791133880615234,
#     'range': 56526,
#     'vol_time_position': 1746710220,
#     'lon': np.float64(107.85314122260735),
#     'lat': np.float64(25.390764960632435)},
#    {'azi': 43.930572509765625,
#     'range': 61543,
#     'vol_time_position': 1746711120,
#     'lon': np.float64(107.93335679826274),
#     'lat': np.float64(25.387431519187423)}],
#   [{'azi': 83.84596252441406,
#     'range': 88042,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(108.37741365309707),
#     'lat': np.float64(25.0717973110813)},
#    {'azi': 81.56449890136719,
#     'range': 94553,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(108.43723437682439),
#     'lat': np.float64(25.111295655472425)},
#    {'azi': 79.57969665527344,
#     'range': 101195,
#     'vol_time_position': 1746710220,
#     'lon': np.float64(108.49709773162334),
#     'lat': np.float64(25.15076985529595)},
#    {'azi': 77.84117126464844,
#     'range': 107943,
#     'vol_time_position': 1746711120,
#     'lon': np.float64(108.55699469336089),
#     'lat': np.float64(25.190218674333725)}],
#   [],
#   [{'azi': 139.737548828125,
#     'range': 11876,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(107.58443606543155),
#     'lat': np.float64(24.90792455044737)},
#    {'azi': 133.42796325683594,
#     'range': 16948,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(107.63035106207741),
#     'lat': np.float64(24.884617224361936)},
#    {'azi': 130.0470733642578,
#     'range': 22132,
#     'vol_time_position': 1746710220,
#     'lon': np.float64(107.67625984320998),
#     'lat': np.float64(24.861286491299218)},
#    {'azi': 127.95366668701172,
#     'range': 27363,
#     'vol_time_position': 1746711120,
#     'lon': np.float64(107.72214573871429),
#     'lat': np.float64(24.837946567981636)}],
#   [],
#   [{'azi': 70.8148193359375,
#     'range': 124083,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(108.67449712910705),
#     'lat': np.float64(25.351578919099566)},
#    {'azi': 71.91266632080078,
#     'range': 129941,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(108.73741806635547),
#     'lat': np.float64(25.347167991677182)}],
#   [{'azi': 85.85530853271484,
#     'range': 199939,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(109.48854145929184),
#     'lat': np.float64(25.106268762786083)}],
#   [{'azi': 84.79219055175781,
#     'range': 6886,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(107.57637571713227),
#     'lat': np.float64(24.99505029820318)}],
#   [],
#   [],
#   [{'azi': 12.851875305175781,
#     'range': 16027,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(107.54374305299301),
#     'lat': np.float64(25.129963914055477)}],
#   [],
#   [{'azi': 73.97261810302734,
#     'range': 110484,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(108.56423388756329),
#     'lat': np.float64(25.260030984627136)}],
#   [],
#   [{'azi': 54.7585563659668,
#     'range': 55827,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(107.96179685739271),
#     'lat': np.float64(25.27845548327336)},
#    {'azi': 52.671451568603516,
#     'range': 62430,
#     'vol_time_position': 1746709320,
#     'lon': np.float64(108.00225072406585),
#     'lat': np.float64(25.329074947655176)},
#    {'azi': 50.9853401184082,
#     'range': 69099,
#     'vol_time_position': 1746710220,
#     'lon': np.float64(108.04273037328062),
#     'lat': np.float64(25.379677668910226)},
#    {'azi': 49.5970344543457,
#     'range': 75818,
#     'vol_time_position': 1746711120,
#     'lon': np.float64(108.08324907487456),
#     'lat': np.float64(25.4302725807119)}],
#   [{'azi': 54.2261962890625,
#     'range': 66580,
#     'vol_time_position': 1746708420,
#     'lon': np.float64(108.0458291747724),
# ...
#    [np.float64(25.020692147658707), np.float64(107.3807185647867)],
#    [np.float64(24.99505029820318), np.float64(107.57637571713227)]],
#   [[np.float64(25.03622354191124), np.float64(107.52989049757853)],
#    [np.float64(25.06268836175304), np.float64(107.5337993678239)],
#    [np.float64(25.129963914055477), np.float64(107.54374305299301)]],
#   [[np.float64(25.26481651931394), np.float64(108.44944106825552)],
#    [np.float64(25.294747899101363), np.float64(108.48911274789077)],
#    [np.float64(25.26272077560556), np.float64(108.499986155324)],
#    [np.float64(25.260030984627136), np.float64(108.56423388756329)]],
#   [[np.float64(25.136653474640948), np.float64(107.83768534372781)],
#    [np.float64(25.146543058755828), np.float64(107.85994480843961)],
#    [np.float64(25.18019023257717), np.float64(107.8676601168999)],
#    [np.float64(25.20345714692716), np.float64(107.88115964444818)],
#    [np.float64(25.21913756469118), np.float64(107.90111151555362)],
#    [np.float64(25.227830607001266), np.float64(107.921385578448)],
#    [np.float64(25.27845548327336), np.float64(107.96179685739271)],
#    [np.float64(25.329074947655176), np.float64(108.00225072406585)],
#    [np.float64(25.379677668910226), np.float64(108.04273037328062)],
#    [np.float64(25.4302725807119), np.float64(108.08324907487456)]],
#   [[np.float64(25.326397314450222), np.float64(107.92894128767631)],
#    [np.float64(25.329824957492697), np.float64(107.96193735209151)],
#    [np.float64(25.33850297259377), np.float64(108.0458291747724)],
#    [np.float64(25.347135587065665), np.float64(108.12973347271782)],
#    [np.float64(25.355722717596194), np.float64(108.21365205063806)],
#    [np.float64(25.364260467053672), np.float64(108.2975776121128)]]],
#  'marker_past': [[np.float64(25.242050532518093),
#    np.float64(106.28456168162822)],
#   [np.float64(25.23246828616585), np.float64(106.36224975124817)],
#   [np.float64(25.209937124110002), np.float64(106.43093654860982)],
#   [np.float64(25.180439845602468), np.float64(106.4824379455096)],
#   [np.float64(25.155034799947696), np.float64(106.54040428593648)],
#   [np.float64(25.252195541418214), np.float64(105.6330827338294)],
#   [np.float64(25.24403937189848), np.float64(105.64659165913166)],
#   [np.float64(25.208893300722572), np.float64(105.68658338475912)],
#   [np.float64(25.175873117566884), np.float64(105.71708300086982)],
#   [np.float64(25.158830593304057), np.float64(105.76788096617582)],
#   [np.float64(25.33667129675289), np.float64(105.99215208597315)],
#   [np.float64(25.33174618015633), np.float64(106.05004405450279)],
#   [np.float64(25.331492139062313), np.float64(106.10741669708668)],
#   [np.float64(25.309189433712085), np.float64(106.12266538736002)],
#   [np.float64(25.302260920703503), np.float64(106.15530572995038)],
#   [np.float64(24.969471030413857), np.float64(107.28841697333544)],
#   [np.float64(24.948712011100596), np.float64(107.32470539828931)],
#   [np.float64(24.901578107891147), np.float64(107.33425420762227)],
#   [np.float64(24.9295527082042), np.float64(107.76967689175007)],
#   [np.float64(24.898549656711772), np.float64(107.11526312868517)],
#   [np.float64(24.86593279093588), np.float64(107.14922587944955)],
#   [np.float64(24.841655769950055), np.float64(107.18490995537456)],
#   [np.float64(24.850849930423028), np.float64(107.24937679793464)],
#   [np.float64(24.799175722177214), np.float64(107.27082358688942)],
#   [np.float64(25.092966322140494), np.float64(107.53537068644442)],
#   [np.float64(25.078157777448748), np.float64(107.58188765638278)],
#   [np.float64(25.05468507842001), np.float64(107.62106737301849)],
#   [np.float64(25.050730315861745), np.float64(107.66063268110918)],
#   [np.float64(25.038710742377905), np.float64(107.7050450041351)],
#   [np.float64(25.05295152877657), np.float64(107.35919990012667)],
#   [np.float64(25.0824753141918), np.float64(107.39295921453663)],
#   [np.float64(25.04919590010322), np.float64(107.44969551513826)],
#   [np.float64(24.9896474686549), np.float64(107.53176617596965)],
#   [np.float64(25.270234965583228), np.float64(105.82905483630822)],
#   [np.float64(25.27418611427497), np.float64(105.85916620942908)],
#   [np.float64(25.27118027790431), np.float64(105.89251155374957)],
#   [np.float64(25.26578323761693), np.float64(105.9318894813353)],
#   [np.float64(25.50743752245707), np.float64(106.0886256746992)],
#   [np.float64(25.498539665422445), np.float64(106.1629519318453)],
#   [np.float64(25.46316159354997), np.float64(106.22061699498592)],
#   [np.float64(25.448460992265037), np.float64(106.30272362629054)],
#   [np.float64(25.147324503515314), np.float64(108.17464391264949)],
#   [np.float64(25.160798028476112), np.float64(108.19542013760713)],
#   [np.float64(25.177149069960592), np.float64(108.23639694015411)],
#   [np.float64(25.178001763364747), np.float64(108.22458830975599)],
#   [np.float64(25.16368947212616), np.float64(108.17908208123512)],
#   [np.float64(24.946726952421646), np.float64(109.49815670733979)],
#   [np.float64(24.469765696634823), np.float64(109.15345152532431)],
#   [np.float64(24.454474433225144), np.float64(109.15867855235503)],
#   [np.float64(24.44722001437866), np.float64(109.17775152272085)],
#   [np.float64(24.443455048318206), np.float64(109.19154619937177)],
#   [np.float64(24.442416731378867), np.float64(109.21977577628415)],
#   [np.float64(25.052429376046515), np.float64(107.43454414414242)],
#   [np.float64(25.029209727109233), np.float64(107.44687999771719)],
#   [np.float64(24.955631361760126), np.float64(107.48734732232082)],
#   [np.float64(24.94468803831803), np.float64(107.58894470433009)],
#   [np.float64(24.92507099664404), np.float64(107.65671211249843)],
#   [np.float64(25.144368499070733), np.float64(108.41973309758038)],
#   [np.float64(25.130873361244383), np.float64(108.43218006812494)],
#   [np.float64(25.220503553848236), np.float64(108.34810115457428)],
#   [np.float64(25.216827593824718), np.float64(108.36498973489239)],
#   [np.float64(25.220271010510864), np.float64(108.3960656237163)],
#   [np.float64(25.205679701645607), np.float64(108.42403155885349)],
#   [np.float64(25.195169646679652), np.float64(108.45982183347019)],
#   [np.float64(24.920566201893877), np.float64(108.02185202927153)],
#   [np.float64(24.935864853664082), np.float64(108.0156306839103)],
#   [np.float64(24.951201431786536), np.float64(108.03418899435476)],
#   [np.float64(24.95788490010271), np.float64(108.0251781032036)],
#   [np.float64(24.98123052310183), np.float64(108.04992562252598)],
#   [np.float64(25.215120885697115), np.float64(108.29652992741242)],
#   [np.float64(25.22366020523032), np.float64(108.33650151258146)],
#   [np.float64(25.22455209046798), np.float64(108.57937956064687)],
#   [np.float64(25.202358744834306), np.float64(108.61366201330686)],
#   [np.float64(24.980634099607627), np.float64(108.07728997018974)],
#   [np.float64(25.025937194387403), np.float64(108.1135498304294)],
#   [np.float64(25.173850594826202), np.float64(108.07798547771714)],
#   [np.float64(25.1588287173628), np.float64(108.09397709094176)],
#   [np.float64(25.195280404757444), np.float64(108.0733842238919)],
#   [np.float64(24.994341850671017), np.float64(110.04038779557868)],
#   [np.float64(25.397738340939128), np.float64(107.48748855879428)],
#   [np.float64(25.41477925245017), np.float64(107.52036435705867)],
#   [np.float64(25.41514093889935), np.float64(107.54920203155753)],
#   [np.float64(25.3967874001146), np.float64(107.58593665286232)],
#   [np.float64(25.00116595089865), np.float64(108.2706300718394)],
#   [np.float64(25.0132678939142), np.float64(108.29915471927798)],
#   [np.float64(24.959641028303494), np.float64(107.45702840061195)],
#   [np.float64(24.98204659301055), np.float64(107.45881517559548)],
#   [np.float64(25.004794039817945), np.float64(107.47373414563012)],
#   [np.float64(24.982895470678017), np.float64(107.48709358262408)],
#   [np.float64(24.929992985384537), np.float64(107.52938224063504)],
#   [np.float64(25.359393424973188), np.float64(108.5620605285695)],
#   [np.float64(25.34504791830557), np.float64(108.57532941167331)],
#   [np.float64(25.05785351482314), np.float64(109.25921940005685)],
#   [np.float64(25.058850918340422), np.float64(109.28559272042659)],
#   [np.float64(25.03070768276111), np.float64(107.3037379012772)],
#   [np.float64(25.03622354191124), np.float64(107.52989049757853)],
#   [np.float64(25.26481651931394), np.float64(108.44944106825552)],
#   [np.float64(25.294747899101363), np.float64(108.48911274789077)],
#   [np.float64(25.136653474640948), np.float64(107.83768534372781)],
#   [np.float64(25.146543058755828), np.float64(107.85994480843961)],
#   [np.float64(25.18019023257717), np.float64(107.8676601168999)],
#   [np.float64(25.20345714692716), np.float64(107.88115964444818)],
#   [np.float64(25.21913756469118), np.float64(107.90111151555362)],
#   [np.float64(25.326397314450222), np.float64(107.92894128767631)]],
#  'marker_current': [[np.float64(25.115412606232596),
#    np.float64(106.58960795900846)],
#   [np.float64(25.12673885979999), np.float64(105.80642733315258)],
#   [np.float64(25.294170026078174), np.float64(106.1721828246575)],
#   [np.float64(24.846225796463372), np.float64(107.33671098189464)],
#   [np.float64(24.91482901218026), np.float64(107.79843203955167)],
#   [np.float64(24.800626061442586), np.float64(107.29788377305752)],
#   [np.float64(25.008100339182892), np.float64(107.77596227479252)],
#   [np.float64(25.004354980825333), np.float64(107.67627217264157)],
#   [np.float64(25.238886065712382), np.float64(106.00296161942234)],
#   [np.float64(25.407330447100662), np.float64(106.34547518609314)],
#   [np.float64(25.170129419342857), np.float64(108.22916738252577)],
#   [np.float64(24.93690265579285), np.float64(109.57165452637491)],
#   [np.float64(24.437894845707252), np.float64(109.24413173848139)],
#   [np.float64(24.937900253853094), np.float64(107.69452331433955)],
#   [np.float64(25.109046163283665), np.float64(108.45352972115802)],
#   [np.float64(25.157643433901786), np.float64(108.49000029949998)],
#   [np.float64(24.994617873726266), np.float64(108.06119334836112)],
#   [np.float64(25.263785153720363), np.float64(108.39534101693611)],
#   [np.float64(25.205626487447038), np.float64(108.64296411515511)],
#   [np.float64(25.054234027565563), np.float64(108.1670510754327)],
#   [np.float64(25.19876065469363), np.float64(108.09198024288557)],
#   [np.float64(25.0466604030195), np.float64(110.12468169378234)],
#   [np.float64(25.40053039672606), np.float64(107.61248638870309)],
#   [np.float64(25.032274907789418), np.float64(108.31763352467004)],
#   [np.float64(24.93122035529446), np.float64(107.53850004293945)],
#   [np.float64(25.35596378825359), np.float64(108.61156955213633)],
#   [np.float64(25.0792156672782), np.float64(109.36017337071934)],
#   [np.float64(25.020692147658707), np.float64(107.3807185647867)],
#   [np.float64(25.06268836175304), np.float64(107.5337993678239)],
#   [np.float64(25.26272077560556), np.float64(108.499986155324)],
#   [np.float64(25.227830607001266), np.float64(107.921385578448)],
#   [np.float64(25.329824957492697), np.float64(107.96193735209151)]],
#  'marker_fst': [[np.float64(25.05013584688251),
#    np.float64(106.74279040005533)],
#   [np.float64(24.98469622893878), np.float64(106.89580713130957)],
#   [np.float64(24.91910010007766), np.float64(107.04866371975851)],
#   [np.float64(25.060091959819843), np.float64(105.89793211199814)],
#   [np.float64(24.99337927657658), np.float64(105.98934149832961)],
#   [np.float64(24.926605661396724), np.float64(106.08065891999854)],
#   [np.float64(24.85977656357947), np.float64(106.1718680949884)],
#   [np.float64(25.270600442719132), np.float64(106.26160759335058)],
#   [np.float64(25.24697313989937), np.float64(106.35099310303673)],
#   [np.float64(25.22329153319199), np.float64(106.44034351649111)],
#   [np.float64(24.74023190658874), np.float64(107.37590033089786)],
#   [np.float64(24.634235222948913), np.float64(107.41502383848753)],
#   [np.float64(24.87737149358173), np.float64(107.871505684311)],
#   [np.float64(24.839878710310742), np.float64(107.94453536299785)],
#   [np.float64(24.802351334064227), np.float64(108.01751882872114)],
#   [np.float64(24.764788754261804), np.float64(108.09045818202549)],
#   [np.float64(24.75107888700468), np.float64(107.3953241166914)],
#   [np.float64(24.701464392155568), np.float64(107.49268191352803)],
#   [np.float64(24.9682361295702), np.float64(107.89297755860494)],
#   [np.float64(24.92828068726479), np.float64(108.00992683190704)],
#   [np.float64(25.22070850600728), np.float64(106.10984256675366)],
#   [np.float64(25.343459140963716), np.float64(106.51140339027859)],
#   [np.float64(25.279396619232458), np.float64(106.67715847887797)],
#   [np.float64(25.179099215167064), np.float64(108.2445543779882)],
#   [np.float64(24.91176456443216), np.float64(109.75844389595396)],
#   [np.float64(24.42339289135914), np.float64(109.29138471182793)],
#   [np.float64(24.40887806362754), np.float64(109.3386256857117)],
#   [np.float64(24.39434871393514), np.float64(109.38585400297407)],
#   [np.float64(24.379802403797253), np.float64(109.43307917126833)],
#   [np.float64(24.87259240498831), np.float64(107.84190521839244)],
#   [np.float64(25.06413365677353), np.float64(108.49646122309682)],
#   [np.float64(25.01921024359719), np.float64(108.53936264045069)],
#   [np.float64(24.974275196360562), np.float64(108.58223252541562)],
#   [np.float64(24.929328653014007), np.float64(108.62506916041657)],
#   [np.float64(25.12896243966336), np.float64(108.56420354553127)],
#   [np.float64(25.100246966227324), np.float64(108.63837583067327)],
#   [np.float64(25.031894539953502), np.float64(108.08233143937422)],
#   [np.float64(25.069167184052162), np.float64(108.103474424534)],
#   [np.float64(25.106437981898395), np.float64(108.12464258190835)],
#   [np.float64(25.143704866369227), np.float64(108.14581872740645)],
#   [np.float64(25.325547761771894), np.float64(108.52105617304719)],
#   [np.float64(25.18152813968606), np.float64(108.72375460531026)],
#   [np.float64(25.157389816582477), np.float64(108.80452486099014)],
#   [np.float64(25.14771238492223), np.float64(108.2813077975113)],
#   [np.float64(25.241097766573596), np.float64(108.39572848896128)],
#   [np.float64(25.334395380697764), np.float64(108.51033692285613)],
#   [np.float64(25.22702446473461), np.float64(108.09741700481764)],
#   [np.float64(25.255290369981058), np.float64(108.10286192610934)],
#   [np.float64(25.28355722946108), np.float64(108.10831165405058)],
#   [np.float64(25.397313504712994), np.float64(107.69270812348634)],
#   [np.float64(25.39406205609589), np.float64(107.7729277725936)],
#   [np.float64(25.390764960632435), np.float64(107.85314122260735)],
#   [np.float64(25.387431519187423), np.float64(107.93335679826274)],
#   [np.float64(25.0717973110813), np.float64(108.37741365309707)],
#   [np.float64(25.111295655472425), np.float64(108.43723437682439)],
#   [np.float64(25.15076985529595), np.float64(108.49709773162334)],
#   [np.float64(25.190218674333725), np.float64(108.55699469336089)],
#   [np.float64(24.90792455044737), np.float64(107.58443606543155)],
#   [np.float64(24.884617224361936), np.float64(107.63035106207741)],
#   [np.float64(24.861286491299218), np.float64(107.67625984320998)],
#   [np.float64(24.837946567981636), np.float64(107.72214573871429)],
#   [np.float64(25.351578919099566), np.float64(108.67449712910705)],
#   [np.float64(25.347167991677182), np.float64(108.73741806635547)],
#   [np.float64(25.106268762786083), np.float64(109.48854145929184)],
#   [np.float64(24.99505029820318), np.float64(107.57637571713227)],
#   [np.float64(25.129963914055477), np.float64(107.54374305299301)],
#   [np.float64(25.260030984627136), np.float64(108.56423388756329)],
#   [np.float64(25.27845548327336), np.float64(107.96179685739271)],
#   [np.float64(25.329074947655176), np.float64(108.00225072406585)],
#   [np.float64(25.379677668910226), np.float64(108.04273037328062)],
#   [np.float64(25.4302725807119), np.float64(108.08324907487456)],
#   [np.float64(25.33850297259377), np.float64(108.0458291747724)],
#   [np.float64(25.347135587065665), np.float64(108.12973347271782)],
#   [np.float64(25.355722717596194), np.float64(108.21365205063806)],
#   [np.float64(25.364260467053672), np.float64(108.2975776121128)]]}

# %% [markdown]
# ## M-中气旋

# %%
#ss
ptype='M'
filepath= rootpath + '/' + staid + '/' + ptype + '/60/'
filename = f'{staid}_{timestr}Z_{ptype}_00_60'
data_mda = decoder.read_mda(filepath,filename)
data_mda
# Out:
# {'meso': [{'feature_id': 1,
#    'storm_id': 81,
#    'azi': 271.897216796875,
#    'range': 95131,
#    'ele': 3.2362582683563232,
#    'ave_shear': 11.841376304626465,
#    'height': 5903,
#    'azi_diam': 5438,
#    'radial_diam': 8500,
#    'ave_rot_spd': 84.43428802490234,
#    'max_rot_spd': 107.7674789428711,
#    'top': 7233,
#    'base': 2828,
#    'base_azi': 4.793832778930664,
#    'base_range': 91,
#    'base_ele': 1.4700003862380981,
#    'max_t_shear': 29.647907257080078,
#    'lon': np.float64(106.56478962419138),
#    'lat': np.float64(25.01479221630309),
#    'storm_id_char': 'C3',
#    'feature_id_char': 'A0',
#    'feature_type': 1},
#   {'feature_id': 2,
#    'storm_id': 26,
#    'azi': 91.65743255615234,
#    'range': 48554,
#    'ele': 8.634995460510254,
#    'ave_shear': 7.118873119354248,
#    'height': 7428,
#    'azi_diam': 5082,
#    'radial_diam': 5500,
#    'ave_rot_spd': 60.423736572265625,
#    'max_rot_spd': 63.55426788330078,
#    'top': 7428,
#    'base': 5424,
#    'base_azi': 1.615432620048523,
#    'base_range': 57,
#    'base_ele': 5.260386943817139,
#    'max_t_shear': 11.162975311279297,
#    'lon': np.float64(107.98982913171538),
#    'lat': np.float64(24.976040530183916),
#    'storm_id_char': 'Z0',
#    'feature_id_char': 'B0',
#    'feature_type': 1},
#   {'feature_id': 3,
#    'storm_id': 11,
#    'azi': 80.22901916503906,
#    'range': 41133,
#    'ele': 6.139969825744629,
#    'ave_shear': 6.504447937011719,
#    'height': 4499,
#    'azi_diam': 4216,
#    'radial_diam': 3250,
#    'ave_rot_spd': 57.82685470581055,
#    'max_rot_spd': 65.2908935546875,
#    'top': 7275,
#    'base': 4499,
#    'base_azi': 1.4002593755722046,
#    'base_range': 41,
#    'base_ele': 6.139969825744629,
#    'max_t_shear': 10.010417938232422,
#    'lon': np.float64(107.91073681757139),
#    'lat': np.float64(25.051681959793445),
#    'storm_id_char': 'K0',
#    'feature_id_char': 'C0',
#    'feature_type': 1}],
#  'feature': [{'feature_id': 1,
#    'storm_id': 81,
#    'feature_type': 1,
#    'azi': 271.897216796875,
#    'range': 95131,
#    'ele': 3.2362582683563232,
#    'height': 5903,
#    'azi_diam': 5438,
#    'radial_diam': 8500,
#    'ave_shear': 6.270174026489258,
#    'max_shear': 11.841376304626465,
#    'ave_rot_spd': 84.43428802490234,
#    'max_rot_spd': 107.7674789428711,
#    'top': 7233,
#    'base': 2828,
#    'base_azi': 4.793832778930664,
#    'base_range': 91188,
#    'base_ele': 84.22489166259766,
#    'lon': np.float64(106.56478962419138),
#    'lat': np.float64(25.01479221630309),
#    'storm_id_char': 'C3',
#    'feature_id_char': 'A0'},
#   {'feature_id': 2,
#    'storm_id': 26,
#    'feature_type': 1,
#    'azi': 91.65743255615234,
#    'range': 48554,
#    'ele': 8.634995460510254,
#    'height': 7428,
#    'azi_diam': 5082,
#    'radial_diam': 5500,
#    'ave_shear': 5.497328758239746,
#    'max_shear': 7.118873119354248,
#    'ave_rot_spd': 60.423736572265625,
#    'max_rot_spd': 63.55426788330078,
#    'top': 7428,
#    'base': 5424,
#    'base_azi': 1.615432620048523,
#    'base_range': 57072,
#    'base_ele': 301.3982238769531,
#    'lon': np.float64(107.98982913171538),
#    'lat': np.float64(24.976040530183916),
#    'storm_id_char': 'Z0',
#    'feature_id_char': 'B0'},
#   {'feature_id': 3,
#    'storm_id': 11,
#    'feature_type': 1,
#    'azi': 80.22901916503906,
#    'range': 41133,
#    'ele': 6.139969825744629,
#    'height': 4499,
#    'azi_diam': 4216,
#    'radial_diam': 3250,
#    'ave_shear': 5.550893306732178,
#    'max_shear': 6.504447937011719,
#    'ave_rot_spd': 57.82685470581055,
#    'max_rot_spd': 65.2908935546875,
#    'top': 7275,
#    'base': 4499,
#    'base_azi': 1.4002593755722046,
#    'base_range': 41133,
#    'base_ele': 351.7946472167969,
#    'lon': np.float64(107.91073681757139),
#    'lat': np.float64(25.051681959793445),
#    'storm_id_char': 'K0',
#    'feature_id_char': 'C0'},
#   {'feature_id': 4,
#    'storm_id': 61,
#    'feature_type': 2,
#    'azi': 81.9680404663086,
#    'range': 78762,
#    'ele': 5.260386943817139,
#    'height': 7586,
#    'azi_diam': 3394,
#    'radial_diam': 16250,
#    'ave_shear': 25.31951141357422,
#    'max_shear': 27.178478240966797,
#    'ave_rot_spd': 153.9882354736328,
#    'max_rot_spd': 154.11109924316406,
#    'top': 7586,
#    'base': 7281,
#    'base_azi': 1.4181994199752808,
#    'base_range': 91521,
#    'base_ele': 243.72711181640625,
#    'lon': np.float64(108.282740756128),
#    'lat': np.float64(25.08640801758267),
#    'storm_id_char': 'I2',
#    'feature_id_char': 'D0'},
#   {'feature_id': 5,
#    'storm_id': 63,
#    'feature_type': 2,
#    'azi': 64.32843780517578,
#    'range': 122880,
#    'ele': 2.3660576343536377,
#    'height': 5961,
#    'azi_diam': 3591,
#    'radial_diam': 41750,
#    'ave_shear': 19.47817611694336,
#    'max_shear': 21.324935913085938,
#    'ave_rot_spd': 136.54681396484375,
#    'max_rot_spd': 143.92910766601562,
#    'top': 7601,
#    'base': 4264,
#    'base_azi': 1.0357942581176758,
#    'base_range': 128411,
#    'base_ele': 84.22489166259766,
#    'lon': np.float64(108.61142805709805),
#    'lat': np.float64(25.464073775639182),
#    'storm_id_char': 'K2',
#    'feature_id_char': 'E0'},
#   {'feature_id': 6,
#    'storm_id': 49,
#    'feature_type': 2,
#    'azi': 69.9052505493164,
#    'range': 64865,
#    'ele': 6.139969825744629,
#    'height': 7185,
#    'azi_diam': 1929,
#    'radial_diam': 2750,
#    'ave_shear': 22.4709529876709,
#    'max_shear': 40.189918518066406,
#    'ave_rot_spd': 94.29342651367188,
#    'max_rot_spd': 129.6544647216797,
#    'top': 7185,
#    'base': 6466,
#    'base_azi': 1.2009040117263794,
#    'base_range': 67602,
#    'base_ele': 301.3982238769531,
#    'lon': np.float64(108.11372157477462),
#    'lat': np.float64(25.1886371836473),
#    'storm_id_char': 'W1',
#    'feature_id_char': 'F0'},
#   {'feature_id': 7,
#    'storm_id': 57,
#    'feature_type': 2,
#    'azi': 80.38619995117188,
#    'range': 67185,
#    'ele': 6.139969825744629,
#    'height': 7451,
#    'azi_diam': 2935,
#    'radial_diam': 19000,
#    'ave_shear': 33.17876052856445,
#    'max_shear': 34.391448974609375,
#    'ave_rot_spd': 166.52392578125,
#    'max_rot_spd': 168.2707061767578,
#    'top': 7451,
#    'base': 6670,
#    'base_azi': 1.3169416189193726,
#    'base_range': 69640,
#    'base_ele': 301.3982238769531,
#    'lon': np.float64(108.16610515882459),
#    'lat': np.float64(25.08890300487573),
#    'storm_id_char': 'E2',
#    'feature_id_char': 'G0'},
#   {'feature_id': 8,
#    'storm_id': 82,
#    'feature_type': 2,
#    'azi': 285.8215637207031,
#    'range': 97780,
#    'ele': 3.2362582683563232,
#    'height': 6082,
#    'azi_diam': 3002,
#    'radial_diam': 5250,
#    'ave_shear': 24.322378158569336,
#    'max_shear': 24.59454917907715,
#    'ave_rot_spd': 127.9441909790039,
#    'max_rot_spd': 131.55882263183594,
#    'top': 7621,
#    'base': 6082,
#    'base_azi': 4.988523006439209,
#    'base_range': 97780,
#    'base_ele': 185.42410278320312,
#    'lon': np.float64(106.573133128239),
#    'lat': np.float64(25.22625869131106),
#    'storm_id_char': 'D3',
#    'feature_id_char': 'H0'},
#   {'feature_id': 9,
#    'storm_id': 26,
#    'feature_type': 2,
#    'azi': 82.63650512695312,
#    'range': 48750,
#    'ele': 8.634995460510254,
#    'height': 7459,
#    'azi_diam': 1875,
#    'radial_diam': 3500,
#    'ave_shear': 32.128997802734375,
#    'max_shear': 59.06929016113281,
#    'ave_rot_spd': 119.31172180175781,
#    'max_rot_spd': 184.67330932617188,
#    'top': 7459,
#    'base': 5336,
#    'base_azi': 1.3860809803009033,
#    'base_range': 48592,
#    'base_ele': 351.7946472167969,
#    'lon': np.float64(107.98825531219293),
#    'lat': np.float64(25.044863780471484),
#    'storm_id_char': 'Z0',
#    'feature_id_char': 'I0'},
#   {'feature_id': 10,
#    'storm_id': 81,
#    'feature_type': 3,
#    'azi': 273.3272399902344,
#    'range': 100799,
#    'ele': 1.4700003862380981,
#    'height': 3183,
#    'azi_diam': 9080,
#    'radial_diam': 3750,
#    'ave_shear': 3.40034556388855,
#    'max_shear': 3.40034556388855,
#    'ave_rot_spd': 51.99687194824219,
#    'max_rot_spd': 51.99687194824219,
#    'top': 3183,
#    'base': 3183,
#    'base_azi': 4.770456314086914,
#    'base_range': 100799,
#    'base_ele': 84.22489166259766,
#    'lon': np.float64(106.50951981041149),
#    'lat': np.float64(25.038720455686644),
#    'storm_id_char': 'C3',
#    'feature_id_char': 'J0'},
#   {'feature_id': 11,
#    'storm_id': 63,
#    'feature_type': 3,
#    'azi': 62.028682708740234,
#    'range': 136707,
#    'ele': 1.4700003862380981,
#    'height': 4607,
#    'azi_diam': 5276,
#    'radial_diam': 17750,
#    'ave_shear': 17.09832763671875,
#    'max_shear': 17.09832763671875,
#    'ave_rot_spd': 147.402587890625,
#    'max_rot_spd': 147.402587890625,
#    'top': 4607,
#    'base': 4607,
#    'base_azi': 1.0826038122177124,
#    'base_range': 136707,
#    'base_ele': 84.22489166259766,
#    'lon': np.float64(108.71184442751857),
#    'lat': np.float64(25.561185033315795),
#    'storm_id_char': 'K2',
#    'feature_id_char': 'K0'},
#   {'feature_id': 12,
#    'storm_id': 68,
#    'feature_type': 3,
#    'azi': 82.04784393310547,
#    'range': 128720,
#    'ele': 2.3660576343536377,
#    'height': 6289,
#    'azi_diam': 6066,
#    'radial_diam': 5000,
#    'ave_shear': 15.956689834594727,
#    'max_shear': 15.956689834594727,
#    'ave_rot_spd': 161.80963134765625,
#    'max_rot_spd': 161.80963134765625,
#    'top': 6289,
#    'base': 6289,
#    'base_azi': 1.4320038557052612,
#    'base_range': 128720,
#    'base_ele': 135.5652313232422,
#    'lon': np.float64(108.77473786245079),
#    'lat': np.float64(25.144220271447114),
#    'storm_id_char': 'P2',
#    'feature_id_char': 'L0'},
#   {'feature_id': 13,
#    'storm_id': 63,
#    'feature_type': 3,
#    'azi': 43.19956588745117,
#    'range': 134318,
#    'ele': 2.3660576343536377,
#    'height': 6607,
#    'azi_diam': 5100,
#    'radial_diam': 22500,
#    'ave_shear': 17.347074508666992,
#    'max_shear': 17.347074508666992,
#    'ave_rot_spd': 147.7345428466797,
#    'max_rot_spd': 147.7345428466797,
#    'top': 6607,
#    'base': 6607,
#    'base_azi': 0.7539740204811096,
#    'base_range': 134318,
#    'base_ele': 135.5652313232422,
#    'lon': np.float64(108.42719160763897),
#    'lat': np.float64(25.86710469582494),
#    'storm_id_char': 'K2',
#    'feature_id_char': 'M0'},
#   {'feature_id': 14,
#    'storm_id': 80,
#    'feature_type': 3,
#    'azi': 40.572547912597656,
#    'range': 86495,
#    'ele': 3.2362582683563232,
#    'height': 5323,
#    'azi_diam': 2727,
#    'radial_diam': 6250,
#    'ave_shear': 32.51937484741211,
#    'max_shear': 32.51937484741211,
#    'ave_rot_spd': 148.37928771972656,
#    'max_rot_spd': 148.37928771972656,
#    'top': 5323,
#    'base': 5323,
#    'base_azi': 0.7081239223480225,
#    'base_range': 86495,
#    'base_ele': 185.42410278320312,
#    'lon': np.float64(108.06921260457729),
#    'lat': np.float64(25.57922627974321),
#    'storm_id_char': 'B3',
#    'feature_id_char': 'N0'},
#   {'feature_id': 15,
#    'storm_id': 80,
#    'feature_type': 3,
#    'azi': 41.40238952636719,
#    'range': 97150,
#    'ele': 3.2362582683563232,
#    'height': 6040,
#    'azi_diam': 2994,
#    'radial_diam': 4250,
#    'ave_shear': 27.07109832763672,
#    'max_shear': 27.07109832763672,
#    'ave_rot_spd': 135.17169189453125,
#    'max_rot_spd': 135.17169189453125,
#    'top': 6040,
#    'base': 6040,
#    'base_azi': 0.722607433795929,
#    'base_range': 97150,
#    'base_ele': 185.42410278320312,
#    'lon': np.float64(108.14923088839299),
#    'lat': np.float64(25.64338131382692),
#    'storm_id_char': 'B3',
#    'feature_id_char': 'O0'},
#   {'feature_id': 16,
#    'storm_id': 68,
#    'feature_type': 3,
#    'azi': 79.33365631103516,
#    'range': 118366,
#    'ele': 3.2362582683563232,
#    'height': 7506,
#    'azi_diam': 3821,
#    'radial_diam': 5000,
#    'ave_shear': 19.480043411254883,
#    'max_shear': 19.480043411254883,
#    'ave_rot_spd': 125.1806411743164,
#    'max_rot_spd': 125.1806411743164,
#    'top': 7506,
#    'base': 7506,
#    'base_azi': 1.3846323490142822,
#    'base_range': 118366,
#    'base_ele': 185.42410278320312,
#    'lon': np.float64(108.66422880927334),
#    'lat': np.float64(25.18198973031102),
#    'storm_id_char': 'P2',
#    'feature_id_char': 'P0'},
#   {'feature_id': 17,
#    'storm_id': 37,
#    'feature_type': 3,
#    'azi': 289.2256164550781,
#    'range': 124641,
#    'ele': 3.2362582683563232,
#    'height': 7950,
#    'azi_diam': 4354,
#    'radial_diam': 5500,
#    'ave_shear': 18.417003631591797,
#    'max_shear': 18.417003631591797,
#    'ave_rot_spd': 133.54083251953125,
#    'max_rot_spd': 133.54083251953125,
#    'top': 7950,
#    'base': 7950,
#    'base_azi': 5.0479350090026855,
#    'base_range': 124641,
#    'base_ele': 185.42410278320312,
#    'lon': np.float64(106.3371870755931),
#    'lat': np.float64(25.35393567288527),
#    'storm_id_char': 'K1',
#    'feature_id_char': 'Q0'},
#   {'feature_id': 18,
#    'storm_id': 80,
#    'feature_type': 3,
#    'azi': 33.533164978027344,
#    'range': 74635,
#    'ele': 4.2538371086120605,
#    'height': 5863,
#    'azi_diam': 2387,
#    'radial_diam': 3250,
#    'ave_shear': 32.132694244384766,
#    'max_shear': 32.132694244384766,
#    'ave_rot_spd': 128.34825134277344,
#    'max_rot_spd': 128.34825134277344,
#    'top': 5863,
#    'base': 5863,
#    'base_azi': 0.5852636694908142,
#    'base_range': 74635,
#    'base_ele': 243.72711181640625,
#    'lon': np.float64(107.91928815997234),
#    'lat': np.float64(25.5483618071577),
#    'storm_id_char': 'B3',
#    'feature_id_char': 'R0'},
#   {'feature_id': 19,
#    'storm_id': 82,
#    'feature_type': 3,
#    'azi': 289.6750183105469,
#    'range': 92346,
#    'ele': 4.2538371086120605,
#    'height': 7351,
#    'azi_diam': 3363,
#    'radial_diam': 3000,
#    'ave_shear': 24.570329666137695,
#    'max_shear': 24.570329666137695,
#    'ave_rot_spd': 136.82040405273438,
#    'max_rot_spd': 136.82040405273438,
#    'top': 7351,
#    'base': 7351,
#    'base_azi': 5.055778503417969,
#    'base_range': 92346,
#    'base_ele': 243.72711181640625,
#    'lon': np.float64(106.64363396883556),
#    'lat': np.float64(25.266544902646867),
#    'storm_id_char': 'D3',
#    'feature_id_char': 'S0'},
#   {'feature_id': 20,
#    'storm_id': 58,
#    'feature_type': 3,
#    'azi': 78.73628997802734,
#    'range': 93165,
#    'ele': 4.2538371086120605,
#    'height': 7421,
#    'azi_diam': 3930,
#    'radial_diam': 4250,
#    'ave_shear': 25.211450576782227,
#    'max_shear': 25.211450576782227,
#    'ave_rot_spd': 165.79563903808594,
#    'max_rot_spd': 165.79563903808594,
#    'top': 7421,
#    'base': 7421,
#    'base_azi': 1.374206304550171,
#    'base_range': 93165,
#    'base_ele': 243.72711181640625,
#    'lon': np.float64(108.41607665736409),
#    'lat': np.float64(25.150336561984357),
#    'storm_id_char': 'F2',
#    'feature_id_char': 'T0'},
#   {'feature_id': 21,
#    'storm_id': 10,
#    'feature_type': 3,
#    'azi': 75.40215301513672,
#    'range': 98617,
#    'ele': 4.2538371086120605,
#    'height': 7887,
#    'azi_diam': 4382,
#    'radial_diam': 4000,
#    'ave_shear': 22.210729598999023,
#    'max_shear': 22.210729598999023,
#    'ave_rot_spd': 162.65394592285156,
#    'max_rot_spd': 162.65394592285156,
#    'top': 7887,
#    'base': 7887,
#    'base_azi': 1.3160147666931152,
#    'base_range': 98617,
#    'base_ele': 243.72711181640625,
#    'lon': np.float64(108.45690052957916),
#    'lat': np.float64(25.209949331227453),
#    'storm_id_char': 'J0',
#    'feature_id_char': 'U0'},
#   {'feature_id': 22,
#    'storm_id': 80,
#    'feature_type': 3,
#    'azi': 35.760040283203125,
#    'range': 68669,
#    'ele': 5.260386943817139,
#    'height': 6573,
#    'azi_diam': 2290,
#    'radial_diam': 7250,
#    'ave_shear': 35.80974578857422,
#    'max_shear': 35.80974578857422,
#    'ave_rot_spd': 136.68533325195312,
#    'max_rot_spd': 136.68533325195312,
#    'top': 6573,
#    'base': 6573,
#    'base_azi': 0.6241298913955688,
#    'base_range': 68669,
#    'base_ele': 301.3982238769531,
#    'lon': np.float64(107.90813009580448),
#    'lat': np.float64(25.490027281022584),
#    'storm_id_char': 'B3',
#    'feature_id_char': 'V0'},
#   {'feature_id': 23,
#    'storm_id': 49,
#    'feature_type': 3,
#    'azi': 67.5521240234375,
#    'range': 55130,
#    'ele': 6.139969825744629,
#    'height': 6075,
#    'azi_diam': 1330,
#    'radial_diam': 2250,
#    'ave_shear': 50.164493560791016,
#    'max_shear': 50.164493560791016,
#    'ave_rot_spd': 111.15083312988281,
#    'max_rot_spd': 111.15083312988281,
#    'top': 6075,
#    'base': 6075,
#    'base_azi': 1.1790059804916382,
#    'base_range': 55130,
#    'base_ele': 351.7946472167969,
#    'lon': np.float64(108.01465911609101),
#    'lat': np.float64(25.177900947548384),
#    'storm_id_char': 'W1',
#    'feature_id_char': 'W0'},
#   {'feature_id': 24,
#    'storm_id': 26,
#    'feature_type': 3,
#    'azi': 97.73057556152344,
#    'range': 62349,
#    'ele': 6.139969825744629,
#    'height': 6897,
#    'azi_diam': 2220,
#    'radial_diam': 11250,
#    'ave_shear': 40.69851303100586,
#    'max_shear': 40.69851303100586,
#    'ave_rot_spd': 150.464599609375,
#    'max_rot_spd': 150.464599609375,
#    'top': 6897,
#    'base': 6897,
#    'base_azi': 1.7057188749313354,
#    'base_range': 62349,
#    'base_ele': 351.7946472167969,
#    'lon': np.float64(108.12094927382256),
#    'lat': np.float64(24.912767423806002),
#    'storm_id_char': 'Z0',
#    'feature_id_char': 'X0'},
#   {'feature_id': 25,
#    'storm_id': 80,
#    'feature_type': 3,
#    'azi': 32.72684860229492,
#    'range': 64932,
#    'ele': 6.139969825744629,
#    'height': 7193,
#    'azi_diam': 2996,
#    'radial_diam': 5000,
#    'ave_shear': 31.195627212524414,
#    'max_shear': 31.195627212524414,
#    'ave_rot_spd': 155.83924865722656,
#    'max_rot_spd': 155.83924865722656,
#    'top': 7193,
#    'base': 7193,
#    'base_azi': 0.5711907744407654,
#    'base_range': 64932,
#    'base_ele': 351.7946472167969,
#    'lon': np.float64(107.8580388690012),
#    'lat': np.float64(25.48027613667113),
#    'storm_id_char': 'B3',
#    'feature_id_char': 'Y0'},
#   {'feature_id': 26,
#    'storm_id': 16,
#    'feature_type': 3,
#    'azi': 71.75929260253906,
#    'range': 70320,
#    'ele': 6.139969825744629,
#    'height': 7812,
#    'azi_diam': 2333,
#    'radial_diam': 4250,
#    'ave_shear': 34.99391174316406,
#    'max_shear': 34.99391174316406,
#    'ave_rot_spd': 136.35643005371094,
#    'max_rot_spd': 136.35643005371094,
#    'top': 7812,
#    'base': 7812,
#    'base_azi': 1.2524348497390747,
#    'base_range': 70320,
#    'base_ele': 351.7946472167969,
#    'lon': np.float64(108.17204155656734),
#    'lat': np.float64(25.185915400112513),
#    'storm_id_char': 'P0',
#    'feature_id_char': 'Z0'},
#   {'feature_id': 27,
#    'storm_id': 13,
#    'feature_type': 3,
#    'azi': 63.14841079711914,
#    'range': 47470,
#    'ele': 8.634995460510254,
#    'height': 7259,
#    'azi_diam': 6309,
#    'radial_diam': 4000,
#    'ave_shear': 5.04557466506958,
#    'max_shear': 5.04557466506958,
#    'ave_rot_spd': 53.89811706542969,
#    'max_rot_spd': 53.89811706542969,
#    'top': 7259,
#    'base': 7259,
#    'base_azi': 1.1021467447280884,
#    'base_range': 47470,
#    'base_ele': 494.74920654296875,
#    'lon': np.float64(107.92920438825495),
#    'lat': np.float64(25.181676672300174),
#    'storm_id_char': 'M0',
#    'feature_id_char': 'A1'}]}

# %% [markdown]
# ## TVS-龙卷涡旋特征

# %%
#ss
ptype='TVS'
filepath= rootpath + '/' + 'Z9852' + '/' + ptype 
filename = f'Z_RADR_I_Z9852_20230421201451_P_DOR_CDD_TVS_NUL_200_NUL_FMT.bin'
data_tvs = decoder.read_tvs(filepath,filename)
data_tvs
# Out:
# {'tvs': [{'storm_id': 251,
#    'type': 1,
#    'azi': 128.61000061035156,
#    'range': 77230,
#    'ele': 0.5,
#    'lldv': 24.5,
#    'adv': 14.0,
#    'mxdv': 24.5,
#    'hmdv': 2057,
#    'depth': 5040,
#    'base': 2057,
#    'top': 7097,
#    'max_shear': 40.3812255859375,
#    'h_max_shear': 2057,
#    'lon': np.float64(107.52244667879229),
#    'lat': np.float64(27.247266445434676),
#    'storm_id_char': 'Q9'}]}

# %% [markdown]
# ## HI-冰雹指数

# %%
#ss
ptype='HI'
filepath= rootpath + '/' + staid + '/' + ptype + '/59/'
filename = f'{staid}_{timestr}Z_{ptype}_00_59'
data_hda = decoder.read_hda(filepath,filename)
data_hda
# Out:
# {'hail': [{'hail_id': 1,
#    'azi': 278.80078125,
#    'range': 93604,
#    'ph': 100,
#    'psh': 100,
#    'hsize': 6.7062506675720215,
#    'rcm_code': 1,
#    'lon': np.float64(106.58960795900846),
#    'lat': np.float64(25.115412606232596),
#    'hail_id_char': 'A0'},
#   {'hail_id': 23,
#    'azi': 275.448974609375,
#    'range': 172132,
#    'ph': 100,
#    'psh': 100,
#    'hsize': 6.307068347930908,
#    'rcm_code': 1,
#    'lon': np.float64(105.80642733315258),
#    'lat': np.float64(25.12673885979999),
#    'hail_id_char': 'W0'},
#   {'hail_id': 9,
#    'azi': 284.42352294921875,
#    'range': 138711,
#    'ph': 100,
#    'psh': 100,
#    'hsize': 3.084573984146118,
#    'rcm_code': 1,
#    'lon': np.float64(106.1721828246575),
#    'lat': np.float64(25.294170026078174),
#    'hail_id_char': 'I0'},
#   {'hail_id': 47,
#    'azi': 227.41697692871094,
#    'range': 23519,
#    'ph': 100,
#    'psh': 100,
#    'hsize': 9.00747013092041,
#    'rcm_code': 1,
#    'lon': np.float64(107.33671098189464),
#    'lat': np.float64(24.846225796463372),
#    'hail_id_char': 'U1'},
#   {'hail_id': 71,
#    'azi': 105.7766342163086,
#    'range': 30401,
#    'ph': 100,
#    'psh': 100,
#    'hsize': 4.391325950622559,
#    'rcm_code': 1,
#    'lon': np.float64(107.79843203955167),
#    'lat': np.float64(24.91482901218026),
#    'hail_id_char': 'S2'},
#   {'hail_id': 2,
#    'azi': 225.35731506347656,
#    'range': 29856,
#    'ph': 100,
#    'psh': 100,
#    'hsize': 9.701375961303711,
#    'rcm_code': 1,
#    'lon': np.float64(107.29788377305752),
#    'lat': np.float64(24.800626061442586),
#    'hail_id_char': 'B0'},
#   {'hail_id': 11,
#    'azi': 85.54539489746094,
#    'range': 27051,
#    'ph': 100,
#    'psh': 100,
#    'hsize': 2.856152296066284,
#    'rcm_code': 1,
#    'lon': np.float64(107.77596227479252),
#    'lat': np.float64(25.008100339182892),
#    'hail_id_char': 'K0'},
#   {'hail_id': 38,
#    'azi': 280.6893310546875,
#    'range': 154098,
#    'ph': 100,
#    'psh': 100,
#    'hsize': 4.26556396484375,
#    'rcm_code': 1,
#    'lon': np.float64(106.00296161942234),
#    'lat': np.float64(25.238886065712382),
#    'hail_id_char': 'L1'},
#   {'hail_id': 21,
#    'azi': 106.94145202636719,
#    'range': 19625,
#    'ph': 100,
#    'psh': 100,
#    'hsize': 3.0420193672180176,
#    'rcm_code': 1,
#    'lon': np.float64(107.69452331433955),
#    'lat': np.float64(24.937900253853094),
#    'hail_id_char': 'U0'},
#   {'hail_id': 16,
#    'azi': 74.37786102294922,
#    'range': 75327,
#    'ph': 90,
#    'psh': 60,
#    'hsize': 1.3338379859924316,
#    'rcm_code': 1,
#    'lon': np.float64(108.22916738252577),
#    'lat': np.float64(25.170129419342857),
#    'hail_id_char': 'P0'},
#   {'hail_id': 72,
#    'azi': 91.17333984375,
#    'range': 208119,
#    'ph': 90,
#    'psh': 60,
#    'hsize': 1.3727068901062012,
#    'rcm_code': 1,
#    'lon': np.float64(109.57165452637491),
#    'lat': np.float64(24.93690265579285),
#    'hail_id_char': 'T2'},
#   {'hail_id': 34,
#    'azi': 154.83177185058594,
#    'range': 7153,
#    'ph': 90,
#    'psh': 60,
#    'hsize': 1.3493412733078003,
#    'rcm_code': 1,
#    'lon': np.float64(107.53850004293945),
#    'lat': np.float64(24.93122035529446),
#    'hail_id_char': 'H1'},
#   {'hail_id': 58,
#    'azi': 81.8488540649414,
#    'range': 96144,
#    'ph': 90,
#    'psh': 50,
#    'hsize': 1.216829776763916,
#    'rcm_code': 1,
#    'lon': np.float64(108.45352972115802),
#    'lat': np.float64(25.109046163283665),
#    'hail_id_char': 'F2'},
#   {'hail_id': 6,
#    'azi': 108.91486358642578,
#    'range': 185778,
#    'ph': 80,
#    'psh': 50,
#    'hsize': 1.230206847190857,
#    'rcm_code': 1,
#    'lon': np.float64(109.24413173848139),
#    'lat': np.float64(24.437894845707252),
#    'hail_id_char': 'F0'},
#   {'hail_id': 57,
#    'azi': 83.66592407226562,
#    'range': 66763,
#    'ph': 70,
#    'psh': 50,
#    'hsize': 1.1537137031555176,
#    'rcm_code': 1,
#    'lon': np.float64(108.1670510754327),
#    'lat': np.float64(25.054234027565563),
#    'hail_id_char': 'E2'},
#   {'hail_id': 26,
#    'azi': 89.29173278808594,
#    'range': 55723,
#    'ph': 70,
#    'psh': 50,
#    'hsize': 1.0753352642059326,
#    'rcm_code': 1,
#    'lon': np.float64(108.06119334836112),
#    'lat': np.float64(24.994617873726266),
#    'hail_id_char': 'Z0'},
#   {'hail_id': 37,
#    'azi': 291.9075927734375,
#    'range': 125897,
#    'ph': 60,
#    'psh': 50,
#    'hsize': 1.2071701288223267,
#    'rcm_code': 1,
#    'lon': np.float64(106.34547518609314),
#    'lat': np.float64(25.407330447100662),
#    'hail_id_char': 'K1'},
#   {'hail_id': 68,
#    'azi': 77.87834167480469,
#    'range': 116762,
#    'ph': 80,
#    'psh': 30,
#    'hsize': 0.8336009383201599,
#    'rcm_code': 2,
#    'lon': np.float64(108.64296411515511),
#    'lat': np.float64(25.205626487447038),
#    'hail_id_char': 'P2'},
#   {'hail_id': 10,
#    'azi': 79.08042907714844,
#    'range': 100628,
#    'ph': 70,
#    'psh': 30,
#    'hsize': 0.7931667566299438,
#    'rcm_code': 2,
#    'lon': np.float64(108.49000029949998),
#    'lat': np.float64(25.157643433901786),
#    'hail_id_char': 'J0'},
#   {'hail_id': 46,
#    'azi': 84.36976623535156,
#    'range': 17006,
#    'ph': 30,
#    'psh': 30,
#    'hsize': 0.8036599159240723,
#    'rcm_code': 2,
#    'lon': np.float64(107.67627217264157),
#    'lat': np.float64(25.004354980825333),
#    'hail_id_char': 'T1'},
#   {'hail_id': 81,
#    'azi': 274.880859375,
#    'range': 103244,
#    'ph': 30,
#    'psh': 0,
#    'hsize': 0.33223074674606323,
#    'rcm_code': 4,
#    'lon': np.float64(106.48706461659148),
#    'lat': np.float64(25.064954766762938),
#    'hail_id_char': 'C3'},
#   {'hail_id': 56,
#    'azi': 70.95120239257812,
#    'range': 94368,
#    'ph': 10,
#    'psh': 0,
#    'hsize': 0.4260061979293823,
#    'rcm_code': 4,
#    'lon': np.float64(108.39534101693611),
#    'lat': np.float64(25.263785153720363),
#    'hail_id_char': 'D2'},
#   {'hail_id': 49,
#    'azi': 68.27226257324219,
#    'range': 63215,
#    'ph': 10,
#    'psh': 0,
#    'hsize': 0.34069111943244934,
#    'rcm_code': 4,
#    'lon': np.float64(108.09198024288557),
#    'lat': np.float64(25.19876065469363),
#    'hail_id_char': 'W1'},
#   {'hail_id': 44,
#    'azi': 12.890445709228516,
#    'range': 46897,
#    'ph': 0,
#    'psh': 0,
#    'hsize': 0.0,
#    'rcm_code': 4,
#    'lon': np.float64(107.61248638870309),
#    'lat': np.float64(25.40053039672606),
#    'hail_id_char': 'R1'},
#   {'hail_id': 61,
#    'azi': 86.48677825927734,
#    'range': 81693,
#    'ph': 0,
#    'psh': 0,
#    'hsize': 0.0,
#    'rcm_code': 4,
#    'lon': np.float64(108.31763352467004),
#    'lat': np.float64(25.032274907789418),
#    'hail_id_char': 'I2'},
#   {'hail_id': 82,
#    'azi': 289.6528625488281,
#    'range': 101143,
#    'ph': 0,
#    'psh': 0,
#    'hsize': 0.0,
#    'rcm_code': 4,
#    'lon': np.float64(106.56093631347268),
#    'lat': np.float64(25.292344825213657),
#    'hail_id_char': 'D3'},
#   {'hail_id': 63,
#    'azi': 69.60863494873047,
#    'range': 118275,
#    'ph': 0,
#    'psh': 0,
#    'hsize': 0.0,
#    'rcm_code': 4,
#    'lon': np.float64(108.61156955213633),
#    'lat': np.float64(25.35596378825359),
#    'hail_id_char': 'K2'},
#   {'hail_id': 59,
#    'azi': 86.54585266113281,
#    'range': 186866,
#    'ph': 0,
#    'psh': 0,
#    'hsize': 0.0,
#    'rcm_code': 4,
#    'lon': np.float64(109.36017337071934),
#    'lat': np.float64(25.0792156672782),
#    'hail_id_char': 'G2'},
#   {'hail_id': 79,
#    'azi': 285.1464538574219,
#    'range': 13321,
#    'ph': 0,
#    'psh': 0,
#    'hsize': 0.0,
#    'rcm_code': 4,
#    'lon': np.float64(107.3807185647867),
#    'lat': np.float64(25.020692147658707),
#    'hail_id_char': 'A3'},
#   {'hail_id': 83,
#    'azi': 122.23287963867188,
#    'range': 19139,
#    'ph': 0,
#    'psh': 0,
#    'hsize': 0.0,
#    'rcm_code': 4,
#    'lon': np.float64(107.6688439112457),
#    'lat': np.float64(24.897555938819625),
#    'hail_id_char': 'E3'},
#   {'hail_id': 84,
#    'azi': 271.69287109375,
#    'range': 48657,
#    'ph': 0,
#    'psh': 0,
#    'hsize': 0.0,
#    'rcm_code': 4,
#    'lon': np.float64(107.02572048068743),
#    'lat': np.float64(25.001593301896815),
#    'hail_id_char': 'F3'},
#   {'hail_id': 75,
#    'azi': 17.482789993286133,
#    'range': 8539,
#    'ph': 0,
#    'psh': 0,
#    'hsize': 0.0,
#    'rcm_code': 4,
#    'lon': np.float64(107.5337993678239),
#    'lat': np.float64(25.06268836175304),
#    'hail_id_char': 'W2'},
#   {'hail_id': 85,
#    'azi': 298.4501953125,
#    'range': 120863,
#    'ph': 0,
#    'psh': 0,
#    'hsize': 0.0,
#    'rcm_code': 4,
#    'lon': np.float64(106.44955176247908),
#    'lat': np.float64(25.503471755255546),
#    'hail_id_char': 'G3'},
#   {'hail_id': 65,
#    'azi': 72.8608169555664,
#    'range': 104360,
#    'ph': 0,
#    'psh': 0,
#    'hsize': 0.0,
#    'rcm_code': 4,
#    'lon': np.float64(108.499986155324),
#    'lat': np.float64(25.26272077560556),
#    'hail_id_char': 'M2'},
#   {'hail_id': 86,
#    'azi': 338.5548400878906,
#    'range': 105482,
#    'ph': 0,
#    'psh': 0,
#    'hsize': 0.0,
#    'rcm_code': 4,
#    'lon': np.float64(107.12290550625654),
#    'lat': np.float64(25.871848887035778),
#    'hail_id_char': 'H3'},
#   {'hail_id': 13,
#    'azi': 57.40081787109375,
#    'range': 49319,
#    'ph': 0,
#    'psh': 0,
#    'hsize': 0.0,
#    'rcm_code': 4,
#    'lon': np.float64(107.921385578448),
#    'lat': np.float64(25.227830607001266),
#    'hail_id_char': 'M0'},
#   {'hail_id': 80,
#    'azi': 50.24363708496094,
#    'range': 59303,
#    'ph': 0,
#    'psh': 0,
#    'hsize': 0.0,
#    'rcm_code': 4,
#    'lon': np.float64(107.96193735209151),
#    'lat': np.float64(25.329824957492697),
#    'hail_id_char': 'B3'}]}

# %% [markdown]
# ## STP-风暴总降水

# %%
#ss
ptype='STP'
filepath= rootpath + '/' + staid + '/' + ptype + '/80/'
filename = f'{staid}_{timestr}Z_{ptype}_00_80'
data_stp = decoder.read_stp(filepath,filename)
outname = f'{filename}.png'
tstr =timestr[0:8]+'_'+timestr[8:14]
draw_latlon(data_stp.data,data_stp.lat.data,data_stp.lon.data,data_stp.lat.min(),data_stp.lat.max(),data_stp.lon.min(),data_stp.lon.max(),outpath,outname,tstr,
            add_title=1,badd_gis=True,
            prefix_title='风暴总降水',units='mm',thred=1,dpi=300)
# Out:
# 产品类型: 27-STP
# 数据类型: 75-累计降水量（Accumulated Precipitation）
# 360 115
# /mnt/e/metradar_test/rose_product/pic/Z9778_20250508123200Z_STP_00_80.png saved!

# %% [markdown]
# ## OHP-1小时降水

# %%
#ss
ptype='OHP'
filepath= rootpath + '/' + staid + '/' + ptype + '/78/'
curtstr = '20250508135433'
filename = f'{staid}_{curtstr}Z_{ptype}_00_78'
data_ohp = decoder.read_ohp(filepath,filename)
outname = f'{filename}.png'
tstr =curtstr[0:8]+'_'+curtstr[8:14]
draw_latlon(data_ohp.data,data_ohp.lat.data,data_ohp.lon.data,data_ohp.lat.min(),data_ohp.lat.max(),data_ohp.lon.min(),data_ohp.lon.max(),outpath,outname,tstr,
            add_title=1,badd_gis=True,
            prefix_title='1小时降水',units='mm',thred=1,dpi=300)
# Out:
# 产品类型: 25-OHP
# 数据类型: 75-累计降水量（Accumulated Precipitation）
# 360 115
# /mnt/e/metradar_test/rose_product/pic/Z9778_20250508135433Z_OHP_00_78.png saved!

# %% [markdown]
# ## VIL-垂直积分液态水

# %%
#ss
ptype='VIL'
filepath= rootpath + '/' + staid + '/' + ptype + '/57/'
filename = f'{staid}_{timestr}Z_{ptype}_00_57'
data_vil = decoder.read_vil(filepath,filename)
outname = f'{filename}.png'
tstr =timestr[0:8]+'_'+timestr[8:14]
draw_latlon(data_vil.data,data_vil.lat.data,data_vil.lon.data,data_vil.lat.min(),data_vil.lat.max(),data_vil.lon.min(),data_vil.lon.max(),outpath,outname,tstr,
            add_title=1,badd_gis=True,
            prefix_title='垂直积分液态水',units='kg/m2',thred=1,dpi=300)
# Out:
# 产品类型: 23-VIL
# 数据类型: 73-垂直积分液态水含量（Vertical Integrated Liquid）
# /mnt/e/metradar_test/rose_product/pic/Z9778_20250508123200Z_VIL_00_57.png saved!

# %% [markdown]
# ## ET-回波顶高

# %%
#ss
ptype='TOPS'
filepath= rootpath + '/' + staid + '/' + ptype + '/41/'
filename = f'{staid}_{timestr}Z_{ptype}_00_41'
data_tops = decoder.read_tops(filepath,filename)
outname = f'{filename}.png'
tstr =timestr[0:8]+'_'+timestr[8:14]
draw_latlon(data_tops.data,data_tops.lat.data,data_tops.lon.data,data_tops.lat.min(),data_tops.lat.max(),data_tops.lon.min(),data_tops.lon.max(),outpath,outname,tstr,
            add_title=1,badd_gis=True,
            prefix_title='回波顶高',units='km',thred=1,dpi=300)
# Out:
# 产品类型: 6-ET
# 数据类型: 72-回波顶高（Echo Top）
# /mnt/e/metradar_test/rose_product/pic/Z9778_20250508123200Z_TOPS_00_41.png saved!
